# %% [markdown]
# # Main Notebook
#
# ### Study context
# Aligning Geneva’s energy-transition policies with public health by quantifying how environmental quality (EQ) intersects with neighborhood morphology. Energy-saving envelopes and densification can unintentionally degrade daylight, heat, noise, and air quality; this notebook links those exposures to health signals.
#
# ### Data at a glance
# - Spatial unit: 250x250 m grid cells across Geneva with harmonized records.
# - Morphology: k-means-derived urban typologies plus detailed morphology indicators (imperviousness, greenness/blue spaces, etc.).
# - EQ layers: land-surface temperature, seasonal solar access, PM10/PM2.5/NO₂, day/night noise.
# - Health indicators: cardiovascular (heart_failure, heart_rhythm), respiratory (d_breath_respiratory, d_breath_asthma), sleep/circadian (points_sleep_deprivation, sleep_disorder_hot, sleeping_hours, bedtime_hour), mental health (GHQ12_case).
# - Controls: demographic and socioeconomic covariates (age, sex, income, education level) to mitigate confounding.
#
# ### Research questions
# 1) Do measurable associations exist between EQ variables and health indicators across neighborhoods?
# 2) In what direction and magnitude do EQ variables influence cardiovascular, respiratory, metabolic, sleep/circadian, and psychosocial outcomes?
# 3) Which urban typologies and morphological characteristics are correlated with health issues?
#
# ### Analytical flow
# - Load integrated morphology + EQ + health data from the Geneva grid.
# - Clean/prune features, inspect distributions, and explore morphology–EQ structure.
# - Aggregate health targets, encode predictors, and filter by association tests and VIF.
# - Train regression/classification models per health dimension; surface residuals/confusion matrices and coefficient importances.
# - Synthesize findings toward policy-ready guidance (risk mapping, resilient typologies).

# %% [markdown]
# ## 1. Load raw morphology data
# Read the integrated morphology CSV with correct separators and decimal marks to establish the working dataframe.

# %%
from pathlib import Path

import sys
import os

root = Path.cwd().parent.parent
if str(root) not in sys.path:
    sys.path.append(str(root))

import pandas as pd
import math
import seaborn as sns
import matplotlib.pyplot as plt
from src.utils.pipeline import (
    load_combined_dataset,
    run_preprocessing_pipeline,
    ohe_features,
)
from src.feature_config import (
    EQ_FEATURES,
    MORPHOLOGY_FEATURES,
    ALL_CONTINUOUS_FEATURES,
    ALL_CATEGORICAL_FEATURES,
    ALL_BINARY_FEATURES,
    POSSIBLE_TARGET_FEATURES,
)
from src.target_definition.aggregate import aggregate_health_targets
from src.feature_selection import (
    compute_associations,
    compute_categorical_associations,
    compute_vif,
    filter_by_p_value,
    filter_by_vif,
    drop_features,
)
from src.predictive import run_modeling_suite

data_path = root / Path("data")
df = pd.read_csv(data_path / "morphology_data_integrated.csv", sep=";", decimal=",")
df.head()
# Out:
#    id        left          top       right       bottom  row_index  col_index  \
# 0  36  2497723.99  1118389.101  2497973.99  1118139.101         10          1
# 1  37  2497723.99  1118139.101  2497973.99  1117889.101         11          1
# 2  38  2497723.99  1117889.101  2497973.99  1117639.101         12          1
# 3  39  2497723.99  1117639.101  2497973.99  1117389.101         13          1
# 4  40  2497723.99  1117389.101  2497973.99  1117139.101         14          1
#
#    field_1       PC1       PC2  ...  Intersections  Length N-S  Length NE-SW  \
# 0     1343  0.526055  0.338480  ...             17      112.14        420.48
# 1     1344  0.851423  0.674067  ...             17      267.99        412.77
# 2     1345 -0.752449  0.148228  ...              1       86.55        183.10
# 3     1346  1.066390 -0.858294  ...              0        0.00          0.00
# 4     1347 -0.433673 -0.642512  ...              0        0.00          0.00
#
#    Length SE-NW Length E-W Length primary road  Length highway  \
# 0         83.42     561.10            0.000000               0
# 1        336.30     412.39          520.689149               0
# 2          0.00      13.60            0.000000               0
# 3          0.00       0.00            0.000000               0
# 4          0.00       0.00            0.000000               0
#
#   Length secondary road  Length railway  Neighbourhood type
# 0           1177.140000         375.314                 S-C
# 1            908.760851           0.000                 S-C
# 2            283.250000           0.000                 S-D
# 3              0.000000           0.000                 S-D
# 4              0.000000           0.000                 S-D
#
# [5 rows x 54 columns]

# %% [markdown]
# ## 2. Initial dataset checks
# Basic row/column counts and category balance for typology.

# %%
print(f"Number of rows: {df.shape[0]}")
print(f"Number of features: {df.shape[1]}")
# Out:
# Number of rows: 241
# Number of features: 54

# %%
df["typology"].value_counts()
# Out:
# typology
# A    58
# E    42
# J    27
# B    26
# C    25
# G    25
# D    20
# I    12
# F     5
# K     1
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Column cleanup and feature pruning
# Standardize names, drop duplicates, metadata, binned variables, and other low-information columns; handle missingness and types.

# %%
# Standardize column names: lowercase and replace spaces with underscores
df = df.drop(columns=["City"])  # remove duplicate column
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_", regex=False)
df.head()
# Out:
#    id        left          top       right       bottom  row_index  col_index  \
# 0  36  2497723.99  1118389.101  2497973.99  1118139.101         10          1
# 1  37  2497723.99  1118139.101  2497973.99  1117889.101         11          1
# 2  38  2497723.99  1117889.101  2497973.99  1117639.101         12          1
# 3  39  2497723.99  1117639.101  2497973.99  1117389.101         13          1
# 4  40  2497723.99  1117389.101  2497973.99  1117139.101         14          1
#
#    field_1       pc1       pc2  ...  intersections  length_n-s  length_ne-sw  \
# 0     1343  0.526055  0.338480  ...             17      112.14        420.48
# 1     1344  0.851423  0.674067  ...             17      267.99        412.77
# 2     1345 -0.752449  0.148228  ...              1       86.55        183.10
# 3     1346  1.066390 -0.858294  ...              0        0.00          0.00
# 4     1347 -0.433673 -0.642512  ...              0        0.00          0.00
#
#    length_se-nw length_e-w length_primary_road  length_highway  \
# 0         83.42     561.10            0.000000               0
# 1        336.30     412.39          520.689149               0
# 2          0.00      13.60            0.000000               0
# 3          0.00       0.00            0.000000               0
# 4          0.00       0.00            0.000000               0
#
#   length_secondary_road  length_railway  neighbourhood_type
# 0           1177.140000         375.314                 S-C
# 1            908.760851           0.000                 S-C
# 2            283.250000           0.000                 S-D
# 3              0.000000           0.000                 S-D
# 4              0.000000           0.000                 S-D
#
# [5 rows x 53 columns]

# %%
print(df.columns.unique())
# Out:
# Index(['id', 'left', 'top', 'right', 'bottom', 'row_index', 'col_index',
#        'field_1', 'pc1', 'pc2', 'pc3', 'pc4', 'pc5', 'pc6', 'typology', 'city',
#        'z_distance', 'q_cluster', 'lst_mean', 'solar_summ', 'solar_wint',
#        'pm10_mean', 'pm25_mean', 'no2_mean', 'noiseday_m', 'noisenight',
#        'bin_lst_me', 'bin_solar_', 'bin_sola_1', 'bin_pm10_m', 'bin_pm25_m',
#        'bin_no2_me', 'bin_noised', 'bin_noisen', 'building_height',
#        'height_varability', 'sky_view_factor', 'frontal_area_index',
#        'water_cover_fraction', 'impervious_surface_cover_fraction',
#        'building_cover_fraction', 'pervious_surface_cover_fraction',
#        'aspect_ratio', 'intersections', 'length_n-s', 'length_ne-sw',
#        'length_se-nw', 'length_e-w', 'length_primary_road', 'length_highway',
#        'length_secondary_road', 'length_railway', 'neighbourhood_type'],
#       dtype='object')

# %%
# Print the columns with unique values == len(df)

cols_to_remove = []
for col in df.columns:
    if col == "id":
        continue
    if df[col].nunique() == len(df) or df[col].nunique() <= 1:
        cols_to_remove.append(col)

print("Columns to remove: ", cols_to_remove)
df = df.drop(columns=cols_to_remove)
# Out:
# Columns to remove:  ['field_1', 'city', 'length_highway']

# %%
features_to_remove = [
    "left",
    "top",
    "right",
    "bottom",
    "row_index",
    "col_index",
    "q_cluster",
    "z_distance",
]
df = df.drop(columns=features_to_remove)
print(f"Numbers of columns after removing metadata features: {len(df.columns)}")
print(df.columns)
# Out:
# Numbers of columns after removing metadata features: 42
# Index(['id', 'pc1', 'pc2', 'pc3', 'pc4', 'pc5', 'pc6', 'typology', 'lst_mean',
#        'solar_summ', 'solar_wint', 'pm10_mean', 'pm25_mean', 'no2_mean',
#        'noiseday_m', 'noisenight', 'bin_lst_me', 'bin_solar_', 'bin_sola_1',
#        'bin_pm10_m', 'bin_pm25_m', 'bin_no2_me', 'bin_noised', 'bin_noisen',
#        'building_height', 'height_varability', 'sky_view_factor',
#        'frontal_area_index', 'water_cover_fraction',
#        'impervious_surface_cover_fraction', 'building_cover_fraction',
#        'pervious_surface_cover_fraction', 'aspect_ratio', 'intersections',
#        'length_n-s', 'length_ne-sw', 'length_se-nw', 'length_e-w',
#        'length_primary_road', 'length_secondary_road', 'length_railway',
#        'neighbourhood_type'],
#       dtype='object')

# %%
# Remove the columns with the "bin" prefix, as they are binned versions of other columns
bin_columns = [col for col in df.columns if col.startswith("bin")]
df = df.drop(columns=bin_columns)
print(f"Numbers of columns after removing binned features: {len(df.columns)}")
print(df.columns)
# Out:
# Numbers of columns after removing binned features: 34
# Index(['id', 'pc1', 'pc2', 'pc3', 'pc4', 'pc5', 'pc6', 'typology', 'lst_mean',
#        'solar_summ', 'solar_wint', 'pm10_mean', 'pm25_mean', 'no2_mean',
#        'noiseday_m', 'noisenight', 'building_height', 'height_varability',
#        'sky_view_factor', 'frontal_area_index', 'water_cover_fraction',
#        'impervious_surface_cover_fraction', 'building_cover_fraction',
#        'pervious_surface_cover_fraction', 'aspect_ratio', 'intersections',
#        'length_n-s', 'length_ne-sw', 'length_se-nw', 'length_e-w',
#        'length_primary_road', 'length_secondary_road', 'length_railway',
#        'neighbourhood_type'],
#       dtype='object')

# %%
# Print the rows where there are NaN values
original_rows_num = df.shape[0]
nan_rows = df[df.isna().any(axis=1)]
df.dropna(inplace=True)
print(f"Number of rows after dropping NaN values: {len(df)}")
print(f"Number of rows dropped: {original_rows_num - len(df)}")
# Out:
# Number of rows after dropping NaN values: 240
# Number of rows dropped: 1

# %%
# Remove numeric columns with zero variance (constant columns)
numeric_cols = df.select_dtypes(include=["number"]).columns
zero_var_cols = [c for c in numeric_cols if abs(df[c].std()) <= 1e-8]
if zero_var_cols:
    print("Zero-variance numeric columns to remove:", zero_var_cols)
    df = df.drop(columns=zero_var_cols)
else:
    print("No zero-variance numeric columns found")
print(f"Columns remaining after removing zero-variance: {len(df.columns)}")
# Out:
# No zero-variance numeric columns found
# Columns remaining after removing zero-variance: 34

# %%
# convert typology to categorical dtype
df["typology"] = df["typology"].astype("category")

# %%
# Save the cleaned dataframe
df.to_csv(data_path / "morphology_data_cleaned.csv", index=False)

# %% [markdown]
# ## 4. Exploratory data analysis
# Inspect structure, distributions, correlations, and typology-specific patterns on the cleaned dataset.

# %% [markdown]
# Compact **Exploratory Data Analysis (EDA)** of the cleaned morphological dataset regarding Geneva neighborhoods. Here we perform sanity checks, look at distributions, correlations, clustering tendencies as well as relationships between environmental quality and morphology-associated markers.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 240 entries, 0 to 240
# Data columns (total 34 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 240 non-null    int64
#  1   pc1                                240 non-null    float64
#  2   pc2                                240 non-null    float64
#  3   pc3                                240 non-null    float64
#  4   pc4                                240 non-null    float64
#  5   pc5                                240 non-null    float64
#  6   pc6                                240 non-null    float64
#  7   typology                           240 non-null    category
#  8   lst_mean                           240 non-null    float64
#  9   solar_summ                         240 non-null    float64
#  10  solar_wint                         240 non-null    float64
#  11  pm10_mean                          240 non-null    float64
#  12  pm25_mean                          240 non-null    float64
#  13  no2_mean                           240 non-null    float64
#  14  noiseday_m                         240 non-null    float64
#  15  noisenight                         240 non-null    float64
#  16  building_height                    240 non-null    float64
#  17  height_varability                  240 non-null    float64
#  18  sky_view_factor                    240 non-null    float64
#  19  frontal_area_index                 240 non-null    float64
#  20  water_cover_fraction               240 non-null    float64
#  21  impervious_surface_cover_fraction  240 non-null    float64
#  22  building_cover_fraction            240 non-null    float64
#  23  pervious_surface_cover_fraction    240 non-null    float64
#  24  aspect_ratio                       240 non-null    float64
#  25  intersections                      240 non-null    int64
#  26  length_n-s                         240 non-null    float64
#  27  length_ne-sw                       240 non-null    float64
#  28  length_se-nw                       240 non-null    float64
#  29  length_e-w                         240 non-null    float64
#  30  length_primary_road                240 non-null    float64
#  31  length_secondary_road              240 non-null    float64
#  32  length_railway                     240 non-null    float64
#  33  neighbourhood_type                 240 non-null    object
# dtypes: category(1), float64(30), int64(2), object(1)
# memory usage: 64.3+ KB

# %% [markdown]
# Some of the features are already standardized, and they are also all continuous except for the id which is an integer and the typology which is a category

# %%
df.describe().T
# Out:
#                                    count        mean          std        min  \
# id                                 240.0  256.554167   110.487722  36.000000
# pc1                                240.0   -0.276652     0.990332  -4.838262
# pc2                                240.0   -0.007602     1.020836  -3.208794
# pc3                                240.0   -0.133991     1.004006  -3.253529
# pc4                                240.0   -0.216103     0.944383  -3.014233
# pc5                                240.0    0.234959     0.814041  -2.517597
# pc6                                240.0    0.268141     1.041847  -2.546661
# lst_mean                           240.0    0.066048     1.013751  -2.398759
# solar_summ                         240.0    0.029420     1.028082  -3.959839
# solar_wint                         240.0    0.040750     0.994545  -2.147976
# pm10_mean                          240.0   -0.180679     1.002244  -2.082967
# pm25_mean                          240.0   -0.204839     1.015255  -1.731402
# no2_mean                           240.0   -0.198237     0.996708  -2.331441
# noiseday_m                         240.0   -0.124486     1.030667  -3.271546
# noisenight                         240.0   -0.110284     1.021023  -3.108031
# building_height                    240.0   16.419073     6.747876   0.000000
# height_varability                  240.0    6.653217     3.287759   0.000000
# sky_view_factor                    240.0    0.618819     0.158092   0.401946
# frontal_area_index                 240.0    0.206075     0.155448   0.000000
# water_cover_fraction               240.0    0.149629     0.313066   0.000000
# impervious_surface_cover_fraction  240.0    0.421925     0.208974   0.000000
# building_cover_fraction            240.0    0.224604     0.152881   0.000000
# pervious_surface_cover_fraction    240.0    0.203996     0.218896   0.000000
# aspect_ratio                       240.0    0.474213     0.276732   0.000000
# intersections                      240.0    9.541667     6.989407   0.000000
# length_n-s                         240.0  211.440417   208.970515   0.000000
# length_ne-sw                       240.0  320.453333   257.823045   0.000000
# length_se-nw                       240.0  313.914542   253.639051   0.000000
# length_e-w                         240.0  199.624042   230.550162   0.000000
# length_primary_road                240.0  467.296505   514.203745   0.000000
# length_secondary_road              240.0  605.662209   524.122774   0.000000
# length_railway                     240.0  293.206975  1507.222420   0.000000
#
#                                           25%         50%         75%  \
# id                                 166.750000  260.500000  344.250000
# pc1                                 -0.906122   -0.138568    0.436716
# pc2                                 -0.583750    0.038594    0.627072
# pc3                                 -0.784161   -0.037030    0.458507
# pc4                                 -0.888022   -0.258895    0.350770
# pc5                                 -0.379032    0.204648    0.693712
# pc6                                 -0.329660    0.208061    0.949746
# lst_mean                            -0.698862   -0.043775    0.783261
# solar_summ                          -0.407195   -0.205333    0.553019
# solar_wint                          -0.514735   -0.192346    0.440508
# pm10_mean                           -0.945075   -0.410620    0.480712
# pm25_mean                           -1.000359   -0.459439    0.453265
# no2_mean                            -0.984631   -0.399462    0.572988
# noiseday_m                          -0.903530   -0.071947    0.576758
# noisenight                          -0.885522   -0.037482    0.532922
# building_height                     14.878403   18.440317   20.847306
# height_varability                    4.985500    7.044500    8.572000
# sky_view_factor                      0.515609    0.559272    0.656310
# frontal_area_index                   0.076250    0.196000    0.320500
# water_cover_fraction                 0.000000    0.000000    0.111000
# impervious_surface_cover_fraction    0.331000    0.460500    0.579250
# building_cover_fraction              0.111750    0.215500    0.327750
# pervious_surface_cover_fraction      0.000000    0.151500    0.321500
# aspect_ratio                         0.287500    0.487000    0.646750
# intersections                        5.000000    9.000000   13.000000
# length_n-s                          13.102500  166.310000  342.585000
# length_ne-sw                        95.780000  284.005000  486.227500
# length_se-nw                        73.795000  296.275000  505.302500
# length_e-w                           0.000000  114.905000  335.187500
# length_primary_road                  0.000000  422.825965  859.318298
# length_secondary_road               66.279323  584.213552  956.827500
# length_railway                       0.000000    0.000000    0.000000
#
#                                             max
# id                                   466.000000
# pc1                                    1.921704
# pc2                                    4.381786
# pc3                                    3.160354
# pc4                                    2.422418
# pc5                                    3.355186
# pc6                                    4.888767
# lst_mean                               2.719456
# solar_summ                             5.038286
# solar_wint                             4.570293
# pm10_mean                              2.377988
# pm25_mean                              2.649498
# no2_mean                               3.068305
# noiseday_m                             2.337904
# noisenight                             2.443605
# building_height                       30.184845
# height_varability                     16.594000
# sky_view_factor                        0.996004
# frontal_area_index                     0.600000
# water_cover_fraction                   1.000000
# impervious_surface_cover_fraction      0.796000
# building_cover_fraction                0.620000
# pervious_surface_cover_fraction        0.852000
# aspect_ratio                           1.356000
# intersections                         35.000000
# length_n-s                           852.780000
# length_ne-sw                        1195.650000
# length_se-nw                         978.550000
# length_e-w                          1068.080000
# length_primary_road                 2005.827967
# length_secondary_road               2139.230000
# length_railway                     14240.014000

# %% [markdown]
# The distributions show significant skewness in several morphological features. Here are some takeaways:
#
# - Gaussian-like: The Environmental Quality (EQ) variables, specifically noise (noiseday_m) and air pollution (pm10_mean, no2_mean), follow a more normal distribution, which is good for regression stability.
#
# - Z-normalization: there are different continuous features with vastly different scales (e.g., road lengths vs. pollution concentrations), Z-normalization will make it so they all fall into a comparable range for the Lasso/Ridge models.
#
# - Zero-Inflation: Variables like length_railway and water_cover_fraction are heavily zero-inflated (most neighborhoods do not contain rails or water). This suggests these might act more like binary "presence/absence" indicators rather than continuous variables in a linear model.

# %%
plt.figure(figsize=(12, 8))
df[MORPHOLOGY_FEATURES + EQ_FEATURES].hist(bins=20, figsize=(14, 10))
plt.tight_layout()
plt.show()

# %% [markdown]
# This plot highlights physical coupling of variables related to the morphology of the neighborhoods. Here are some takeaways:
#
# - The "Canyon" Effect: There is a notable negative correlation between building_height and sky_view_factor. As buildings get taller, the visible sky decreases, which physically makes sense.
#
# - Pollutant Clustering: The bottom right corner shows a dense red block among pm10_mean, pm25_mean, and no2_mean. This indicates extremely high multicollinearity. In the regression models, this will make it difficult to determine which specific pollutant is causing a health outcome, as they all move together.
#
# - Morphology Drivers: impervious_surface_cover_fraction correlates positively with temperature (lst_mean), confirming the urban effect where concrete traps heat.

# %%
NUMERICAL_MORPHOLOGY_FEATURES = [
    feature for feature in MORPHOLOGY_FEATURES if feature in ALL_CONTINUOUS_FEATURES
]

plt.figure(figsize=(12, 10))
sns.heatmap(
    df[NUMERICAL_MORPHOLOGY_FEATURES + EQ_FEATURES].corr(),
    annot=False,
    cmap="coolwarm",
    center=0,
)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# This confirms the linearity of the relationships seen in the heatmap. The scatter plots between PM10, PM2.5, and NO2 are almost straight lines. This implies that measuring one provides almost all the information needed to predict the other.

# %%
# pairplot for compact visual overview to show all pairwise scatter plots, maybe catch nonlinear relations
sns.pairplot(df[EQ_FEATURES], diag_kind="kde")
plt.suptitle("Environmental Features - All Pairwise Scatterplots", y=1.02)
plt.show()

# %% [markdown]
# This serves as a check to validate if the k-means derived typologies (A, B, C... J) are meaningful. In fact, we see that the typologies capture distinct morphological profiles. For example, Typology I is starkly defined by a high `water_cover_fraction` and corresponding low `impervious_surface_cover_fraction`, identifying it as a water-dominated cluster. Similarly, Typology F is uniquely isolated by an extreme outlier in `length_railway`, suggesting it represents transport infrastructure zones.
#
# Also, the inter-quartile ranges for different typologies often do not overlap, indicating clear statistical separation. This confirms that the clustering was computed on the morphological features rather than the environmental outcomes.

# %%
# arrange the env feature boxplots into a single grid of subplots
n = len(NUMERICAL_MORPHOLOGY_FEATURES)
cols = min(3, n)
rows = math.ceil(n / cols)
fig, axes = plt.subplots(rows, cols, figsize=(cols * 5, rows * 3), squeeze=False)
axes_flat = axes.flatten()

for ax, var in zip(axes_flat, NUMERICAL_MORPHOLOGY_FEATURES):
    sns.boxplot(data=df, x="typology", y=var, ax=ax)
    ax.set_title(f"{var} across typologies")
    plt.xticks(rotation=45)

# remove any unused axes (if n < rows*cols)
for ax in axes_flat[len(NUMERICAL_MORPHOLOGY_FEATURES) :]:
    fig.delaxes(ax)

plt.tight_layout()
plt.show()

# %% [markdown]
# In contrast to the previous plots, here we see that for the environmental outcomes (like `lst_mean`, `pm10_mean`, and `noiseday_m`), there is much higher variance within groups and significant overlap between them. While there are visible trends, for instance denser typologies like A and B tend to have slightly higher NO2 means, the distinctions are not sharp. A specific value for `pm25_mean` could plausibly belong to almost any typology.
#
# This confirms that the environmental variables are likely consequences or correlates of the morphological types, rather than the primary drivers used to define the clusters. If the clustering had been driven by temperature or pollution, we would see tight, clearly separated boxes in these environmental charts and likely much more overlap in the morphological ones.

# %%
# arrange the env feature boxplots into a single grid of subplots
n = len(EQ_FEATURES)
cols = min(3, n)
rows = math.ceil(n / cols)
fig, axes = plt.subplots(rows, cols, figsize=(cols * 5, rows * 3), squeeze=False)
axes_flat = axes.flatten()

for ax, var in zip(axes_flat, EQ_FEATURES):
    sns.boxplot(data=df, x="typology", y=var, ax=ax)
    ax.set_title(f"{var} across typologies")
    plt.xticks(rotation=45)

# remove any unused axes (if n < rows*cols)
for ax in axes_flat[len(EQ_FEATURES) :]:
    fig.delaxes(ax)

plt.tight_layout()
plt.show()

# %% [markdown]
# PCA components show non-zero mutual correlations, so they are not independent; we will drop them instead of using the PCA basis.

# %%
PCA_cols = [col for col in df.columns if col.startswith("pc")]

plt.figure(figsize=(10, 8))
sns.heatmap(
    df[PCA_cols].corr(),
    annot=False,
    cmap="coolwarm",
    center=0,
)
plt.title("PCA Component Correlations")
plt.show()

# %% [markdown]
# ## 5. Modeling pipeline setup
# Load combined morphology + synthetic health data and run preprocessing before feature typing.

# %%
# ABLATION STUDY OPTIONS
# Set these to False to disable the corresponding step
ONE_HOT_ENCODING = True
FEATURE_SELECTION = True
STANDARD_SCALING = True
CLASS_BALANCING = False
HYPERPARAMETER_REFINING = False

# %%
df = load_combined_dataset(
    data_path / "morphology_data_cleaned.csv",
    data_path / "health_data_synthetic.xlsx",
)
df = run_preprocessing_pipeline(df)
# df = df.sample(frac=0.1, random_state=42).reset_index(
#     drop=True
# )  # shuffle the dataset and reduce it by 90% for quick training

print(f"Final dataset shape: {df.shape}")
# Out:
# Final dataset shape: (11877, 40)

# %%
df.head()
# Out:
#   typology  lst_mean  solar_summ  solar_wint  pm10_mean  pm25_mean  no2_mean  \
# 0        C -0.111053    1.130211    0.982144  -1.361464  -1.464034 -1.538696
# 1        C -0.111053    1.130211    0.982144  -1.361464  -1.464034 -1.538696
# 2        C -0.111053    1.130211    0.982144  -1.361464  -1.464034 -1.538696
# 3        C -0.111053    1.130211    0.982144  -1.361464  -1.464034 -1.538696
# 4        C -0.111053    1.130211    0.982144  -1.361464  -1.464034 -1.538696
#
#    noiseday_m  noisenight  building_height  ...  heart_failure  heart_rhythm  \
# 0   -1.409763   -1.450883        15.782626  ...              0             0
# 1   -1.409763   -1.450883        15.782626  ...              0             0
# 2   -1.409763   -1.450883        15.782626  ...              0             0
# 3   -1.409763   -1.450883        15.782626  ...              0             0
# 4   -1.409763   -1.450883        15.782626  ...              0             0
#
#    d_breath_respiratory  d_breath_asthma  GHQ12_case  \
# 0                     0                0            2
# 1                     1                0            6
# 2                     0                0            2
# 3                     0                0            3
# 4                     0                0            4
#
#    points_sleep_deprivation  sleep_disorder_hot  sleeping_hours  bedtime_hour  \
# 0                         2                   0        7.336321     23.716667
# 1                         6                   0        4.779276     20.816667
# 2                         3                   1        9.489910     22.266667
# 3                         2                   1        5.763730     23.450000
# 4                         3                   0        6.465778     22.366667
#
#    age_bin
# 0        5
# 1        3
# 2        4
# 3        6
# 4        3
#
# [5 rows x 40 columns]

# %% [markdown]
# We only have 28 continuous features so we decided not to apply PCA on them.

# %%
print(
    f"Number of features that are continuous: {len([col for col in df.columns if col in ALL_CONTINUOUS_FEATURES and col not in POSSIBLE_TARGET_FEATURES])}",
)
# Out:
# Number of features that are continuous: 28

# %%
all_feature_types = {}
for column in df.columns:
    if column in ALL_CONTINUOUS_FEATURES:
        all_feature_types[column] = "continuous"
    elif column in ALL_CATEGORICAL_FEATURES:
        all_feature_types[column] = "categorical"
    elif column in ALL_BINARY_FEATURES:
        all_feature_types[column] = "binary"
    else:
        non_null_values = df[column].dropna()
        if not non_null_values.empty and non_null_values.isin([0, 1]).all():
            all_feature_types[column] = "binary"
        else:
            all_feature_types[column] = "continuous"

# %% [markdown]
# ## 6. Feature selection per target
# Aggregate health targets, test associations, apply p-value and VIF filters, and persist cleaned feature sets.
#
# Each health outcome will have its own trimmed dataset with only the useful predictors (after p-values, VIF, and one-hot encoding).

# %%
datasets = {
    "cardiovascular": aggregate_health_targets(
        df, target_feature="cardiovascular", feature_types=all_feature_types
    ),
    "mental_health": aggregate_health_targets(
        df, target_feature="mental_health", feature_types=all_feature_types
    ),
    "sleep_disorder": aggregate_health_targets(
        df, target_feature="sleep_disorder", feature_types=all_feature_types
    ),
    "respiratory": aggregate_health_targets(
        df, target_feature="respiratory", feature_types=all_feature_types
    ),
}

# %%
for name, dataset_with_info in datasets.items():
    print(f"\n=== Analyzing target type: {name} ===")

    dataset = dataset_with_info["data"]
    feature_types = dataset_with_info["feature_types"]

    if not FEATURE_SELECTION:
        # Optional OHE even when skipping feature selection
        dataset, feature_types = ohe_features(
            dataset,
            feature_types,
            enable=ONE_HOT_ENCODING,
        )
        print(
            "Feature selection disabled: retaining all predictors without p-value/VIF filtering."
        )
        print("\nSelected features:")
        print([col for col in dataset.columns if col != "target"])
        datasets[name]["data"] = dataset
        datasets[name]["feature_types"] = feature_types
        continue

    # compute associations for categorical features before one-hot encoding
    categorical_association_df = compute_categorical_associations(
        dataset,
        "target",
        feature_types,
    )
    if categorical_association_df is not None and not categorical_association_df.empty:
        display(categorical_association_df)

        # keep categorical predictors that are significant
        passed_by_p = filter_by_p_value(categorical_association_df)

        dropped_categorical_features = [
            feature
            for feature in dataset.columns
            if feature in ALL_CATEGORICAL_FEATURES and feature not in passed_by_p
        ]

        dataset, feature_types = drop_features(
            dataset,
            feature_types,
            dropped_categorical_features,
        )
        print(
            f"Categorical features dropped because they did not pass p-value thresholds: \n {dropped_categorical_features}"
        )

    # one hot encoding of categorical features
    dataset, feature_types = ohe_features(
        dataset,
        feature_types,
        enable=ONE_HOT_ENCODING,
    )

    # compute all association tests
    association_df = compute_associations(
        dataset,
        "target",
        feature_types,
    )

    # filter out features that are not significant in any of our association tests
    passed_by_p = filter_by_p_value(association_df)
    feature_names_to_keep = set(passed_by_p)

    dropped_features_by_p_value = [
        feature
        for feature in dataset.columns
        if feature not in feature_names_to_keep and feature != "target"
    ]
    dataset, feature_types = drop_features(
        dataset,
        feature_types,
        dropped_features_by_p_value,
    )
    print(
        f"Features dropped because they did not pass p-value thresholds: \n {dropped_features_by_p_value}"
    )

    vif_df = pd.DataFrame(compute_vif(dataset, feature_types))
    if not vif_df.empty:
        vif_df = vif_df.sort_values(by="statistic_value", ascending=False)

        passed_by_vif = set(filter_by_vif(vif_df))
        dropped_features_by_VIF = [
            feature
            for feature, ftype in feature_types.items()
            if ftype == "continuous"
            and feature not in passed_by_vif
            and feature != "target"
        ]
        dataset, feature_types = drop_features(
            dataset,
            feature_types,
            dropped_features_by_VIF,
        )
        print(
            f"Features dropped because they did not pass VIF thresholds: \n {dropped_features_by_VIF}"
        )
    else:
        print(
            "Skipped VIF step: no continuous features or insufficient data; nothing dropped."
        )

    print("\nSelected features:")
    selected_features = [col for col in dataset.columns if col != "target"]
    print(selected_features)
    print()

    # Save changes to dataset
    datasets[name]["data"] = dataset
    datasets[name]["feature_types"] = feature_types

    for test_name, subset in association_df.groupby("test", sort=False):
        print(f"\nTest: {test_name}")
        display(subset.reset_index(drop=True))

    if vif_df is not None and vif_df.empty is False:
        print(f"\nTest: VIF")
        display(
            vif_df.drop(columns=["p_value"], errors="ignore").reset_index(drop=True)
        )
# Out:
# === Analyzing target type: cardiovascular ===
#             predictor predictor_type        test statistic_name  \
# 0  neighbourhood_type    categorical  Chi-square           chi2
# 1            typology    categorical  Chi-square           chi2
#
#    statistic_value   p_value
# 0         5.108211  0.883833
# 1         2.808973  0.945767
# Categorical features dropped because they did not pass p-value thresholds:
#  ['typology', 'neighbourhood_type']
# Features dropped because they did not pass p-value thresholds:
#  ['lst_mean', 'solar_summ', 'solar_wint', 'building_height', 'height_varability', 'frontal_area_index', 'impervious_surface_cover_fraction', 'building_cover_fraction', 'aspect_ratio', 'intersections', 'length_n-s', 'length_ne-sw', 'length_e-w', 'length_primary_road', 'length_secondary_road', 'sex', 'education_level']
# Features dropped because they did not pass VIF thresholds:
#  []
#
# Selected features:
# ['pm10_mean', 'pm25_mean', 'no2_mean', 'noiseday_m', 'noisenight', 'sky_view_factor', 'water_cover_fraction', 'pervious_surface_cover_fraction', 'length_se-nw', 'length_railway', 'income', 'age_bin']
#
#
# Test: Univariate logistic regression
#                             predictor predictor_type  \
# 0                             age_bin     continuous
# 1                          noisenight     continuous
# 2                            no2_mean     continuous
# 3     pervious_surface_cover_fraction     continuous
# 4                          noiseday_m     continuous
# 5                           pm10_mean     continuous
# 6                           pm25_mean     continuous
# 7                     sky_view_factor     continuous
# 8                      length_railway     continuous
# 9                        length_se-nw     continuous
# 10               water_cover_fraction     continuous
# 11                             income     continuous
# 12                    education_level     continuous
# 13                length_primary_road     continuous
# 14  impervious_surface_cover_fraction     continuous
# 15                      intersections     continuous
# 16                    building_height     continuous
# 17                         length_e-w     continuous
# 18                  height_varability     continuous
# 19              length_secondary_road     continuous
# 20                 frontal_area_index     continuous
# 21            building_cover_fraction     continuous
# 22                       aspect_ratio     continuous
# 23                         solar_wint     continuous
# 24                         solar_summ     continuous
# 25                         length_n-s     continuous
# 26                           lst_mean     continuous
# 27                                sex         binary
# 28                       length_ne-sw     continuous
#
#                               test statistic_name  statistic_value  \
# 0   Univariate logistic regression     odds_ratio         1.514138
# 1   Univariate logistic regression     odds_ratio         1.081876
# 2   Univariate logistic regression     odds_ratio         1.078352
# 3   Univariate logistic regression     odds_ratio         0.722244
# 4   Univariate logistic regression     odds_ratio         1.071216
# 5   Univariate logistic regression     odds_ratio         1.069873
# 6   Univariate logistic regression     odds_ratio         1.060624
# 7   Univariate logistic regression     odds_ratio         1.295083
# 8   Univariate logistic regression     odds_ratio         1.000023
# 9   Univariate logistic regression     odds_ratio         0.999869
# 10  Univariate logistic regression     odds_ratio         1.100109
# 11  Univariate logistic regression     odds_ratio         0.973213
# 12  Univariate logistic regression     odds_ratio         1.033461
# 13  Univariate logistic regression     odds_ratio         1.000037
# 14  Univariate logistic regression     odds_ratio         1.093824
# 15  Univariate logistic regression     odds_ratio         0.997239
# 16  Univariate logistic regression     odds_ratio         0.997482
# 17  Univariate logistic regression     odds_ratio         1.000065
# 18  Univariate logistic regression     odds_ratio         0.996015
# 19  Univariate logistic regression     odds_ratio         0.999976
# 20  Univariate logistic regression     odds_ratio         0.923378
# 21  Univariate logistic regression     odds_ratio         1.078925
# 22  Univariate logistic regression     odds_ratio         1.022996
# 23  Univariate logistic regression     odds_ratio         0.994877
# 24  Univariate logistic regression     odds_ratio         0.995879
# 25  Univariate logistic regression     odds_ratio         1.000019
# 26  Univariate logistic regression     odds_ratio         1.001877
# 27  Univariate logistic regression     odds_ratio         0.996985
# 28  Univariate logistic regression     odds_ratio         0.999995
#
#          p_value
# 0   4.361712e-31
# 1   1.978266e-02
# 2   2.821518e-02
# 3   4.216330e-02
# 4   4.244863e-02
# 5   4.961614e-02
# 6   8.258990e-02
# 7   2.278467e-01
# 8   2.820037e-01
# 9   3.574067e-01
# 10  3.730333e-01
# 11  4.388106e-01
# 12  5.083772e-01
# 13  5.817423e-01
# 14  5.894747e-01
# 15  5.927144e-01
# 16  6.207911e-01
# 17  6.805284e-01
# 18  7.054764e-01
# 19  7.199667e-01
# 20  7.230381e-01
# 21  7.409613e-01
# 22  8.604329e-01
# 23  8.849045e-01
# 24  9.065093e-01
# 25  9.126817e-01
# 26  9.564176e-01
# 27  9.652663e-01
# 28  9.680224e-01
# Test: Chi-square
#   predictor predictor_type        test statistic_name  statistic_value  \
# 0       sex         binary  Chi-square           chi2         0.000079
#
#     p_value
# 0  0.992921
# Test: VIF
#                           predictor predictor_type test statistic_name  \
# 0                         pm10_mean     continuous  VIF            VIF
# 1                         pm25_mean     continuous  VIF            VIF
# 2                          no2_mean     continuous  VIF            VIF
# 3                        noisenight     continuous  VIF            VIF
# 4                        noiseday_m     continuous  VIF            VIF
# 5              water_cover_fraction     continuous  VIF            VIF
# 6                   sky_view_factor     continuous  VIF            VIF
# 7                      length_se-nw     continuous  VIF            VIF
# 8                    length_railway     continuous  VIF            VIF
# 9   pervious_surface_cover_fraction     continuous  VIF            VIF
# 10                          age_bin     continuous  VIF            VIF
# 11                           income     continuous  VIF            VIF
#
#     statistic_value
# 0         27.166995
# 1         13.688014
# 2         13.521891
# 3         11.501790
# 4         10.773214
# 5          8.068533
# 6          7.079438
# 7          1.572050
# 8          1.558447
# 9          1.555329
# 10         1.001395
# 11         1.000927
# === Analyzing target type: mental_health ===
#             predictor predictor_type   test statistic_name  statistic_value  \
# 0            typology    categorical  ANOVA              F          0.37845
# 1  neighbourhood_type    categorical  ANOVA              F          0.35686
#
#     p_value
# 0  0.932590
# 1  0.964694
# Categorical features dropped because they did not pass p-value thresholds:
#  ['typology', 'neighbourhood_type']
# Features dropped because they did not pass p-value thresholds:
#  ['solar_summ', 'solar_wint', 'pm25_mean', 'noisenight', 'building_height', 'height_varability', 'length_se-nw', 'length_e-w', 'length_railway']
# Features dropped because they did not pass VIF thresholds:
#  ['water_cover_fraction', 'impervious_surface_cover_fraction', 'building_cover_fraction', 'pervious_surface_cover_fraction']
#
# Selected features:
# ['lst_mean', 'pm10_mean', 'no2_mean', 'noiseday_m', 'sky_view_factor', 'frontal_area_index', 'aspect_ratio', 'intersections', 'length_n-s', 'length_ne-sw', 'length_primary_road', 'length_secondary_road', 'sex', 'income', 'education_level', 'age_bin']
#
#
# Test: Univariate linear regression
#                             predictor predictor_type  \
# 0                              income     continuous
# 1               length_secondary_road     continuous
# 2                             age_bin     continuous
# 3                     education_level     continuous
# 4                        aspect_ratio     continuous
# 5             building_cover_fraction     continuous
# 6                  frontal_area_index     continuous
# 7                            no2_mean     continuous
# 8                           pm10_mean     continuous
# 9   impervious_surface_cover_fraction     continuous
# 10                length_primary_road     continuous
# 11                           lst_mean     continuous
# 12                         length_n-s     continuous
# 13               water_cover_fraction     continuous
# 14                                sex         binary
# 15                    sky_view_factor     continuous
# 16                       length_ne-sw     continuous
# 17                  height_varability     continuous
# 18    pervious_surface_cover_fraction     continuous
# 19                          pm25_mean     continuous
# 20                         noiseday_m     continuous
# 21                    building_height     continuous
# 22                      intersections     continuous
# 23                         length_e-w     continuous
# 24                       length_se-nw     continuous
# 25                         solar_summ     continuous
# 26                         solar_wint     continuous
# 27                         noisenight     continuous
# 28                     length_railway     continuous
#
#                             test                           statistic_name  \
# 0   Univariate linear regression                             coef[income]
# 1   Univariate linear regression              coef[length_secondary_road]
# 2   Univariate linear regression                            coef[age_bin]
# 3   Univariate linear regression                    coef[education_level]
# 4   Univariate linear regression                       coef[aspect_ratio]
# 5   Univariate linear regression            coef[building_cover_fraction]
# 6   Univariate linear regression                 coef[frontal_area_index]
# 7   Univariate linear regression                           coef[no2_mean]
# 8   Univariate linear regression                          coef[pm10_mean]
# 9   Univariate linear regression  coef[impervious_surface_cover_fraction]
# 10  Univariate linear regression                coef[length_primary_road]
# 11  Univariate linear regression                           coef[lst_mean]
# 12  Univariate linear regression                         coef[length_n-s]
# 13  Univariate linear regression               coef[water_cover_fraction]
# 14  Univariate linear regression                                coef[sex]
# 15  Univariate linear regression                    coef[sky_view_factor]
# 16  Univariate linear regression                       coef[length_ne-sw]
# 17  Univariate linear regression                  coef[height_varability]
# 18  Univariate linear regression    coef[pervious_surface_cover_fraction]
# 19  Univariate linear regression                          coef[pm25_mean]
# 20  Univariate linear regression                         coef[noiseday_m]
# 21  Univariate linear regression                    coef[building_height]
# 22  Univariate linear regression                      coef[intersections]
# 23  Univariate linear regression                         coef[length_e-w]
# 24  Univariate linear regression                       coef[length_se-nw]
# 25  Univariate linear regression                         coef[solar_summ]
# 26  Univariate linear regression                         coef[solar_wint]
# 27  Univariate linear regression                         coef[noisenight]
# 28  Univariate linear regression                     coef[length_railway]
#
#     statistic_value       p_value
# 0     -3.674430e-02  7.914573e-36
# 1     -1.036720e-05  7.114867e-02
# 2     -4.964748e-03  7.432885e-02
# 3     -5.742179e-03  1.715210e-01
# 4     -1.323240e-02  2.262093e-01
# 5     -2.266989e-02  2.439287e-01
# 6     -2.060712e-02  2.771519e-01
# 7     -3.180603e-03  2.816720e-01
# 8     -3.137672e-03  2.874864e-01
# 9     -1.387018e-02  3.210850e-01
# 10     5.675988e-06  3.241073e-01
# 11    -2.609606e-03  3.682902e-01
# 12    -1.259667e-05  3.793278e-01
# 13     7.844570e-03  3.980116e-01
# 14    -4.911726e-03  4.020072e-01
# 15     1.492779e-02  4.206705e-01
# 16    -7.013370e-06  5.438462e-01
# 17    -5.295445e-04  5.537548e-01
# 18     7.001543e-03  5.940756e-01
# 19    -1.536609e-03  5.979827e-01
# 20    -1.488567e-03  5.997372e-01
# 21    -2.266491e-04  6.022091e-01
# 22    -2.092455e-04  6.299415e-01
# 23    -5.206987e-06  6.976660e-01
# 24    -3.831122e-06  7.489666e-01
# 25     7.601554e-04  7.978371e-01
# 26    -6.684705e-04  8.231203e-01
# 27    -3.318711e-04  9.068805e-01
# 28     2.207884e-07  9.116319e-01
# Test: Pearson correlation
#                             predictor predictor_type                 test  \
# 0                              income     continuous  Pearson correlation
# 1               length_secondary_road     continuous  Pearson correlation
# 2                             age_bin     continuous  Pearson correlation
# 3                     education_level     continuous  Pearson correlation
# 4                        aspect_ratio     continuous  Pearson correlation
# 5             building_cover_fraction     continuous  Pearson correlation
# 6                  frontal_area_index     continuous  Pearson correlation
# 7                            no2_mean     continuous  Pearson correlation
# 8                           pm10_mean     continuous  Pearson correlation
# 9   impervious_surface_cover_fraction     continuous  Pearson correlation
# 10                length_primary_road     continuous  Pearson correlation
# 11                           lst_mean     continuous  Pearson correlation
# 12                         length_n-s     continuous  Pearson correlation
# 13               water_cover_fraction     continuous  Pearson correlation
# 14                    sky_view_factor     continuous  Pearson correlation
# 15                       length_ne-sw     continuous  Pearson correlation
# 16                  height_varability     continuous  Pearson correlation
# 17    pervious_surface_cover_fraction     continuous  Pearson correlation
# 18                          pm25_mean     continuous  Pearson correlation
# 19                         noiseday_m     continuous  Pearson correlation
# 20                    building_height     continuous  Pearson correlation
# 21                      intersections     continuous  Pearson correlation
# 22                         length_e-w     continuous  Pearson correlation
# 23                       length_se-nw     continuous  Pearson correlation
# 24                         solar_summ     continuous  Pearson correlation
# 25                         solar_wint     continuous  Pearson correlation
# 26                         noisenight     continuous  Pearson correlation
# 27                     length_railway     continuous  Pearson correlation
#
#    statistic_name  statistic_value       p_value
# 0               r        -0.114292  7.914573e-36
# 1               r        -0.016559  7.114867e-02
# 2               r        -0.016376  7.432885e-02
# 3               r        -0.012547  1.715210e-01
# 4               r        -0.011105  2.262093e-01
# 5               r        -0.010693  2.439287e-01
# 6               r        -0.009973  2.771519e-01
# 7               r        -0.009879  2.816720e-01
# 8               r        -0.009761  2.874864e-01
# 9               r        -0.009105  3.210850e-01
# 10              r         0.009049  3.241073e-01
# 11              r        -0.008256  3.682902e-01
# 12              r        -0.008068  3.793278e-01
# 13              r         0.007756  3.980116e-01
# 14              r         0.007390  4.206705e-01
# 15              r        -0.005570  5.438462e-01
# 16              r        -0.005434  5.537548e-01
# 17              r         0.004891  5.940756e-01
# 18              r        -0.004839  5.979827e-01
# 19              r        -0.004816  5.997372e-01
# 20              r        -0.004783  6.022091e-01
# 21              r        -0.004421  6.299415e-01
# 22              r        -0.003565  6.976660e-01
# 23              r        -0.002937  7.489666e-01
# 24              r         0.002351  7.978371e-01
# 25              r        -0.002051  8.231203e-01
# 26              r        -0.001073  9.068805e-01
# 27              r         0.001018  9.116319e-01
# Test: Spearman correlation
#                             predictor predictor_type                  test  \
# 0                              income     continuous  Spearman correlation
# 1                             age_bin     continuous  Spearman correlation
# 2               length_secondary_road     continuous  Spearman correlation
# 3                     education_level     continuous  Spearman correlation
# 4                        aspect_ratio     continuous  Spearman correlation
# 5                            no2_mean     continuous  Spearman correlation
# 6                 length_primary_road     continuous  Spearman correlation
# 7             building_cover_fraction     continuous  Spearman correlation
# 8                            lst_mean     continuous  Spearman correlation
# 9                           pm10_mean     continuous  Spearman correlation
# 10                      intersections     continuous  Spearman correlation
# 11                         length_n-s     continuous  Spearman correlation
# 12                 frontal_area_index     continuous  Spearman correlation
# 13  impervious_surface_cover_fraction     continuous  Spearman correlation
# 14                       length_ne-sw     continuous  Spearman correlation
# 15    pervious_surface_cover_fraction     continuous  Spearman correlation
# 16                         noiseday_m     continuous  Spearman correlation
# 17                          pm25_mean     continuous  Spearman correlation
# 18                         length_e-w     continuous  Spearman correlation
# 19                  height_varability     continuous  Spearman correlation
# 20                         solar_wint     continuous  Spearman correlation
# 21                    sky_view_factor     continuous  Spearman correlation
# 22                       length_se-nw     continuous  Spearman correlation
# 23               water_cover_fraction     continuous  Spearman correlation
# 24                         noisenight     continuous  Spearman correlation
# 25                    building_height     continuous  Spearman correlation
# 26                         solar_summ     continuous  Spearman correlation
# 27                     length_railway     continuous  Spearman correlation
#
#    statistic_name  statistic_value       p_value
# 0             rho        -0.113250  3.324539e-35
# 1             rho        -0.018254  4.667281e-02
# 2             rho        -0.015443  9.239242e-02
# 3             rho        -0.012516  1.726078e-01
# 4             rho        -0.012034  1.897106e-01
# 5             rho        -0.011453  2.120052e-01
# 6             rho         0.010914  2.343221e-01
# 7             rho        -0.010849  2.371063e-01
# 8             rho        -0.010427  2.558684e-01
# 9             rho        -0.010368  2.585305e-01
# 10            rho        -0.010051  2.733848e-01
# 11            rho        -0.009983  2.766453e-01
# 12            rho        -0.009974  2.770697e-01
# 13            rho        -0.008870  3.337698e-01
# 14            rho        -0.008444  3.574933e-01
# 15            rho         0.007429  4.181822e-01
# 16            rho        -0.006906  4.517030e-01
# 17            rho        -0.005902  5.201330e-01
# 18            rho        -0.005615  5.405988e-01
# 19            rho        -0.004937  5.905974e-01
# 20            rho        -0.004718  6.071785e-01
# 21            rho         0.003881  6.723555e-01
# 22            rho        -0.002649  7.728611e-01
# 23            rho        -0.002506  7.848318e-01
# 24            rho        -0.002368  7.964023e-01
# 25            rho        -0.001093  9.051664e-01
# 26            rho        -0.000770  9.331037e-01
# 27            rho         0.000559  9.514117e-01
# Test: Point-biserial correlation
#   predictor predictor_type                        test statistic_name  \
# 0       sex         binary  Point-biserial correlation           r_pb
#
#    statistic_value   p_value
# 0         -0.00769  0.402007
# Test: VIF
#                             predictor predictor_type test statistic_name  \
# 0                water_cover_fraction     continuous  VIF            VIF
# 1     pervious_surface_cover_fraction     continuous  VIF            VIF
# 2   impervious_surface_cover_fraction     continuous  VIF            VIF
# 3             building_cover_fraction     continuous  VIF            VIF
# 4                           pm10_mean     continuous  VIF            VIF
# 5                            no2_mean     continuous  VIF            VIF
# 6               length_secondary_road     continuous  VIF            VIF
# 7                     sky_view_factor     continuous  VIF            VIF
# 8                 length_primary_road     continuous  VIF            VIF
# 9                  frontal_area_index     continuous  VIF            VIF
# 10                      intersections     continuous  VIF            VIF
# 11                       aspect_ratio     continuous  VIF            VIF
# 12                       length_ne-sw     continuous  VIF            VIF
# 13                         length_n-s     continuous  VIF            VIF
# 14                         noiseday_m     continuous  VIF            VIF
# 15                           lst_mean     continuous  VIF            VIF
# 16                             income     continuous  VIF            VIF
# 17                             target     continuous  VIF            VIF
# 18                    education_level     continuous  VIF            VIF
# 19                            age_bin     continuous  VIF            VIF
#
#     statistic_value
# 0       6351.096639
# 1       3169.472278
# 2       2801.370265
# 3       1458.654833
# 4         14.992170
# 5         13.227545
# 6         10.535285
# 7          9.429049
# 8          8.660021
# 9          8.127670
# 10         5.466183
# 11         5.339980
# 12         3.758482
# 13         2.604491
# 14         2.143339
# 15         1.596930
# 16         1.015244
# 17         1.014211
# 18         1.001839
# 19         1.001669
# === Analyzing target type: sleep_disorder ===
#             predictor predictor_type   test statistic_name  statistic_value  \
# 0            typology    categorical  ANOVA              F          0.96276
# 1  neighbourhood_type    categorical  ANOVA              F          0.66281
#
#     p_value
# 0  0.463155
# 1  0.759991
# Categorical features dropped because they did not pass p-value thresholds:
#  ['neighbourhood_type']
# Features dropped because they did not pass p-value thresholds:
#  ['lst_mean', 'noiseday_m', 'aspect_ratio', 'intersections', 'length_n-s', 'length_se-nw', 'length_e-w', 'length_secondary_road', 'length_railway', 'typology_B', 'typology_D', 'typology_F', 'typology_G']
# Features dropped because they did not pass VIF thresholds:
#  ['water_cover_fraction', 'impervious_surface_cover_fraction', 'building_cover_fraction', 'pervious_surface_cover_fraction']
#
# Selected features:
# ['solar_summ', 'solar_wint', 'pm10_mean', 'pm25_mean', 'no2_mean', 'noisenight', 'building_height', 'height_varability', 'sky_view_factor', 'frontal_area_index', 'length_ne-sw', 'length_primary_road', 'sex', 'income', 'education_level', 'age_bin', 'typology_A', 'typology_C', 'typology_E', 'typology_I', 'typology_J']
#
#
# Test: Spearman correlation
#                             predictor predictor_type                  test  \
# 0                              income     continuous  Spearman correlation
# 1                     education_level     continuous  Spearman correlation
# 2     pervious_surface_cover_fraction     continuous  Spearman correlation
# 3                             age_bin     continuous  Spearman correlation
# 4                   height_varability     continuous  Spearman correlation
# 5                            no2_mean     continuous  Spearman correlation
# 6             building_cover_fraction     continuous  Spearman correlation
# 7                           pm10_mean     continuous  Spearman correlation
# 8                        length_ne-sw     continuous  Spearman correlation
# 9                water_cover_fraction     continuous  Spearman correlation
# 10                          pm25_mean     continuous  Spearman correlation
# 11                         noisenight     continuous  Spearman correlation
# 12                 frontal_area_index     continuous  Spearman correlation
# 13                length_primary_road     continuous  Spearman correlation
# 14                         solar_wint     continuous  Spearman correlation
# 15                         length_n-s     continuous  Spearman correlation
# 16                       length_se-nw     continuous  Spearman correlation
# 17                       aspect_ratio     continuous  Spearman correlation
# 18                           lst_mean     continuous  Spearman correlation
# 19                    sky_view_factor     continuous  Spearman correlation
# 20                     length_railway     continuous  Spearman correlation
# 21                         solar_summ     continuous  Spearman correlation
# 22                         noiseday_m     continuous  Spearman correlation
# 23                    building_height     continuous  Spearman correlation
# 24              length_secondary_road     continuous  Spearman correlation
# 25                         length_e-w     continuous  Spearman correlation
# 26                      intersections     continuous  Spearman correlation
# 27  impervious_surface_cover_fraction     continuous  Spearman correlation
#
#    statistic_name  statistic_value   p_value
# 0             rho        -0.018155  0.047871
# 1             rho         0.013890  0.130116
# 2             rho         0.013323  0.146523
# 3             rho        -0.012917  0.159231
# 4             rho         0.010044  0.273726
# 5             rho        -0.009215  0.315274
# 6             rho        -0.008419  0.358904
# 7             rho        -0.008177  0.372902
# 8             rho         0.007776  0.396787
# 9             rho        -0.007741  0.398900
# 10            rho        -0.007058  0.441848
# 11            rho        -0.006334  0.490081
# 12            rho        -0.006318  0.491153
# 13            rho         0.005942  0.517289
# 14            rho         0.005824  0.525637
# 15            rho        -0.005776  0.529077
# 16            rho         0.005738  0.531817
# 17            rho        -0.005129  0.576239
# 18            rho         0.004990  0.586634
# 19            rho         0.004746  0.605016
# 20            rho        -0.004551  0.619969
# 21            rho         0.004549  0.620073
# 22            rho        -0.004430  0.629275
# 23            rho        -0.003466  0.705698
# 24            rho         0.002193  0.811133
# 25            rho         0.001591  0.862344
# 26            rho         0.001017  0.911751
# 27            rho        -0.000463  0.959785
# Test: Point-biserial correlation
#     predictor predictor_type                        test statistic_name  \
# 0  typology_E         binary  Point-biserial correlation           r_pb
# 1  typology_J         binary  Point-biserial correlation           r_pb
# 2  typology_I         binary  Point-biserial correlation           r_pb
# 3  typology_C         binary  Point-biserial correlation           r_pb
# 4         sex         binary  Point-biserial correlation           r_pb
# 5  typology_A         binary  Point-biserial correlation           r_pb
# 6  typology_G         binary  Point-biserial correlation           r_pb
# 7  typology_F         binary  Point-biserial correlation           r_pb
# 8  typology_B         binary  Point-biserial correlation           r_pb
# 9  typology_D         binary  Point-biserial correlation           r_pb
#
#    statistic_value   p_value
# 0         0.016695  0.068847
# 1        -0.013932  0.128946
# 2        -0.010802  0.239156
# 3        -0.009235  0.314242
# 4         0.007999  0.383397
# 5         0.006657  0.468167
# 6         0.004236  0.644397
# 7        -0.002407  0.793125
# 8        -0.001967  0.830239
# 9        -0.000953  0.917285
# Test: Univariate linear regression
#                             predictor predictor_type  \
# 0                          typology_E         binary
# 1                   height_varability     continuous
# 2                        length_ne-sw     continuous
# 3                          typology_J         binary
# 4                     education_level     continuous
# 5                          solar_wint     continuous
# 6                 length_primary_road     continuous
# 7                              income     continuous
# 8                          solar_summ     continuous
# 9                water_cover_fraction     continuous
# 10                         typology_I         binary
# 11    pervious_surface_cover_fraction     continuous
# 12                         typology_C         binary
# 13                          pm25_mean     continuous
# 14                    building_height     continuous
# 15                                sex         binary
# 16                    sky_view_factor     continuous
# 17                          pm10_mean     continuous
# 18                           no2_mean     continuous
# 19                         typology_A         binary
# 20  impervious_surface_cover_fraction     continuous
# 21                            age_bin     continuous
# 22                         length_e-w     continuous
# 23                      intersections     continuous
# 24              length_secondary_road     continuous
# 25                         length_n-s     continuous
# 26                         typology_G         binary
# 27                       aspect_ratio     continuous
# 28                         noisenight     continuous
# 29                         typology_F         binary
# 30                       length_se-nw     continuous
# 31                 frontal_area_index     continuous
# 32                         typology_B         binary
# 33                     length_railway     continuous
# 34                         typology_D         binary
# 35                           lst_mean     continuous
# 36                         noiseday_m     continuous
# 37            building_cover_fraction     continuous
#
#                             test                           statistic_name  \
# 0   Univariate linear regression                         coef[typology_E]
# 1   Univariate linear regression                  coef[height_varability]
# 2   Univariate linear regression                       coef[length_ne-sw]
# 3   Univariate linear regression                         coef[typology_J]
# 4   Univariate linear regression                    coef[education_level]
# 5   Univariate linear regression                         coef[solar_wint]
# 6   Univariate linear regression                coef[length_primary_road]
# 7   Univariate linear regression                             coef[income]
# 8   Univariate linear regression                         coef[solar_summ]
# 9   Univariate linear regression               coef[water_cover_fraction]
# 10  Univariate linear regression                         coef[typology_I]
# 11  Univariate linear regression    coef[pervious_surface_cover_fraction]
# 12  Univariate linear regression                         coef[typology_C]
# 13  Univariate linear regression                          coef[pm25_mean]
# 14  Univariate linear regression                    coef[building_height]
# 15  Univariate linear regression                                coef[sex]
# 16  Univariate linear regression                    coef[sky_view_factor]
# 17  Univariate linear regression                          coef[pm10_mean]
# 18  Univariate linear regression                           coef[no2_mean]
# 19  Univariate linear regression                         coef[typology_A]
# 20  Univariate linear regression  coef[impervious_surface_cover_fraction]
# 21  Univariate linear regression                            coef[age_bin]
# 22  Univariate linear regression                         coef[length_e-w]
# 23  Univariate linear regression                      coef[intersections]
# 24  Univariate linear regression              coef[length_secondary_road]
# 25  Univariate linear regression                         coef[length_n-s]
# 26  Univariate linear regression                         coef[typology_G]
# 27  Univariate linear regression                       coef[aspect_ratio]
# 28  Univariate linear regression                         coef[noisenight]
# 29  Univariate linear regression                         coef[typology_F]
# 30  Univariate linear regression                       coef[length_se-nw]
# 31  Univariate linear regression                 coef[frontal_area_index]
# 32  Univariate linear regression                         coef[typology_B]
# 33  Univariate linear regression                     coef[length_railway]
# 34  Univariate linear regression                         coef[typology_D]
# 35  Univariate linear regression                           coef[lst_mean]
# 36  Univariate linear regression                         coef[noiseday_m]
# 37  Univariate linear regression            coef[building_cover_fraction]
#
#     statistic_value   p_value
# 0      1.045513e-02  0.068847
# 1      1.209228e-03  0.073367
# 2      1.424014e-05  0.102674
# 3     -1.056536e-02  0.128946
# 4      4.774067e-03  0.132254
# 5      3.234783e-03  0.152044
# 6      5.699047e-06  0.189868
# 7     -2.678859e-03  0.229239
# 8      2.656369e-03  0.235915
# 9     -8.268111e-03  0.238179
# 10    -1.195114e-02  0.239156
# 11     1.036361e-02  0.296233
# 12    -7.910336e-03  0.314242
# 13    -2.192649e-03  0.319095
# 14     3.008459e-04  0.359610
# 15     3.858221e-03  0.383397
# 16    -1.149723e-02  0.411522
# 17    -1.825681e-03  0.412513
# 18    -1.687709e-03  0.449410
# 19     3.784344e-03  0.468167
# 20     7.359954e-03  0.485709
# 21    -1.447737e-03  0.490812
# 22     6.663017e-06  0.510395
# 23     1.833577e-04  0.576133
# 24    -2.342677e-06  0.589267
# 25    -5.223424e-06  0.629310
# 26     3.153225e-03  0.644397
# 27     3.449467e-03  0.676157
# 28    -5.699472e-04  0.790240
# 29    -3.747991e-03  0.793125
# 30     2.233137e-06  0.804921
# 31    -3.505708e-03  0.806617
# 32    -1.542404e-03  0.830239
# 33     3.100287e-07  0.836520
# 34    -8.334272e-04  0.917285
# 35     2.017372e-04  0.926626
# 36     1.182004e-04  0.955998
# 37    -4.587044e-04  0.975096
# Test: Pearson correlation
#                             predictor predictor_type                 test  \
# 0                   height_varability     continuous  Pearson correlation
# 1                        length_ne-sw     continuous  Pearson correlation
# 2                     education_level     continuous  Pearson correlation
# 3                          solar_wint     continuous  Pearson correlation
# 4                 length_primary_road     continuous  Pearson correlation
# 5                              income     continuous  Pearson correlation
# 6                          solar_summ     continuous  Pearson correlation
# 7                water_cover_fraction     continuous  Pearson correlation
# 8     pervious_surface_cover_fraction     continuous  Pearson correlation
# 9                           pm25_mean     continuous  Pearson correlation
# 10                    building_height     continuous  Pearson correlation
# 11                    sky_view_factor     continuous  Pearson correlation
# 12                          pm10_mean     continuous  Pearson correlation
# 13                           no2_mean     continuous  Pearson correlation
# 14  impervious_surface_cover_fraction     continuous  Pearson correlation
# 15                            age_bin     continuous  Pearson correlation
# 16                         length_e-w     continuous  Pearson correlation
# 17                      intersections     continuous  Pearson correlation
# 18              length_secondary_road     continuous  Pearson correlation
# 19                         length_n-s     continuous  Pearson correlation
# 20                       aspect_ratio     continuous  Pearson correlation
# 21                         noisenight     continuous  Pearson correlation
# 22                       length_se-nw     continuous  Pearson correlation
# 23                 frontal_area_index     continuous  Pearson correlation
# 24                     length_railway     continuous  Pearson correlation
# 25                           lst_mean     continuous  Pearson correlation
# 26                         noiseday_m     continuous  Pearson correlation
# 27            building_cover_fraction     continuous  Pearson correlation
#
#    statistic_name  statistic_value   p_value
# 0               r         0.016430  0.073367
# 1               r         0.014976  0.102674
# 2               r         0.013813  0.132254
# 3               r         0.013144  0.152044
# 4               r         0.012030  0.189868
# 5               r        -0.011033  0.229239
# 6               r         0.010877  0.235915
# 7               r        -0.010824  0.238179
# 8               r         0.009585  0.296233
# 9               r        -0.009143  0.319095
# 10              r         0.008407  0.359610
# 11              r        -0.007536  0.411522
# 12              r        -0.007520  0.412513
# 13              r        -0.006941  0.449410
# 14              r         0.006398  0.485709
# 15              r        -0.006323  0.490812
# 16              r         0.006040  0.510395
# 17              r         0.005130  0.576133
# 18              r        -0.004955  0.589267
# 19              r        -0.004430  0.629310
# 20              r         0.003833  0.676157
# 21              r        -0.002441  0.790240
# 22              r         0.002267  0.804921
# 23              r        -0.002246  0.806617
# 24              r         0.001894  0.836520
# 25              r         0.000845  0.926626
# 26              r         0.000506  0.955998
# 27              r        -0.000286  0.975096
# Test: VIF
#                             predictor predictor_type test statistic_name  \
# 0                water_cover_fraction     continuous  VIF            VIF
# 1     pervious_surface_cover_fraction     continuous  VIF            VIF
# 2   impervious_surface_cover_fraction     continuous  VIF            VIF
# 3             building_cover_fraction     continuous  VIF            VIF
# 4                           pm10_mean     continuous  VIF            VIF
# 5                            no2_mean     continuous  VIF            VIF
# 6                           pm25_mean     continuous  VIF            VIF
# 7                     sky_view_factor     continuous  VIF            VIF
# 8                  frontal_area_index     continuous  VIF            VIF
# 9                     building_height     continuous  VIF            VIF
# 10                         solar_summ     continuous  VIF            VIF
# 11                         solar_wint     continuous  VIF            VIF
# 12                  height_varability     continuous  VIF            VIF
# 13                         noisenight     continuous  VIF            VIF
# 14                       length_ne-sw     continuous  VIF            VIF
# 15                length_primary_road     continuous  VIF            VIF
# 16                    education_level     continuous  VIF            VIF
# 17                             income     continuous  VIF            VIF
# 18                             target     continuous  VIF            VIF
# 19                            age_bin     continuous  VIF            VIF
#
#     statistic_value
# 0       6323.888924
# 1       3154.540777
# 2       2784.767120
# 3       1452.680396
# 4         28.953010
# 5         13.653740
# 6         13.182474
# 7          8.195504
# 8          7.607077
# 9          3.612429
# 10         3.132400
# 11         3.025081
# 12         2.454819
# 13         2.449717
# 14         1.866240
# 15         1.360917
# 16         1.002336
# 17         1.001956
# 18         1.001407
# 19         1.001400
# === Analyzing target type: respiratory ===
#             predictor predictor_type        test statistic_name  \
# 0  neighbourhood_type    categorical  Chi-square           chi2
# 1            typology    categorical  Chi-square           chi2
#
#    statistic_value   p_value
# 0        10.371355  0.408539
# 1         5.953962  0.652389
# Categorical features dropped because they did not pass p-value thresholds:
#  ['typology']
# Features dropped because they did not pass p-value thresholds:
#  ['lst_mean', 'solar_summ', 'solar_wint', 'pm10_mean', 'pm25_mean', 'no2_mean', 'noiseday_m', 'building_height', 'height_varability', 'sky_view_factor', 'water_cover_fraction', 'building_cover_fraction', 'pervious_surface_cover_fraction', 'aspect_ratio', 'intersections', 'length_n-s', 'length_ne-sw', 'length_se-nw', 'length_secondary_road', 'length_railway', 'sex', 'income', 'education_level', 'neighbourhood_type_G-B', 'neighbourhood_type_G-D', 'neighbourhood_type_G-F', 'neighbourhood_type_S-D', 'neighbourhood_type_S-E']
# Features dropped because they did not pass VIF thresholds:
#  []
#
# Selected features:
# ['noisenight', 'frontal_area_index', 'impervious_surface_cover_fraction', 'length_e-w', 'length_primary_road', 'age_bin', 'neighbourhood_type_G-A', 'neighbourhood_type_G-C', 'neighbourhood_type_G-E', 'neighbourhood_type_S-A', 'neighbourhood_type_S-B', 'neighbourhood_type_S-C']
#
#
# Test: Univariate logistic regression
#                             predictor predictor_type  \
# 0                             age_bin     continuous
# 1              neighbourhood_type_S-B         binary
# 2   impervious_surface_cover_fraction     continuous
# 3              neighbourhood_type_S-C         binary
# 4                 length_primary_road     continuous
# 5              neighbourhood_type_G-C         binary
# 6                          length_e-w     continuous
# 7              neighbourhood_type_G-A         binary
# 8              neighbourhood_type_G-E         binary
# 9                          noisenight     continuous
# 10             neighbourhood_type_S-A         binary
# 11                 frontal_area_index     continuous
# 12             neighbourhood_type_G-D         binary
# 13                     length_railway     continuous
# 14                    building_height     continuous
# 15                         solar_summ     continuous
# 16                      intersections     continuous
# 17             neighbourhood_type_S-E         binary
# 18               water_cover_fraction     continuous
# 19            building_cover_fraction     continuous
# 20             neighbourhood_type_S-D         binary
# 21             neighbourhood_type_G-F         binary
# 22             neighbourhood_type_G-B         binary
# 23                         solar_wint     continuous
# 24                       length_se-nw     continuous
# 25    pervious_surface_cover_fraction     continuous
# 26                         noiseday_m     continuous
# 27                    education_level     continuous
# 28                    sky_view_factor     continuous
# 29                             income     continuous
# 30                         length_n-s     continuous
# 31              length_secondary_road     continuous
# 32                                sex         binary
# 33                       length_ne-sw     continuous
# 34                  height_varability     continuous
# 35                           lst_mean     continuous
# 36                          pm10_mean     continuous
# 37                           no2_mean     continuous
# 38                       aspect_ratio     continuous
# 39                          pm25_mean     continuous
#
#                               test statistic_name  statistic_value   p_value
# 0   Univariate logistic regression     odds_ratio         1.118048  0.000007
# 1   Univariate logistic regression     odds_ratio         0.807925  0.015429
# 2   Univariate logistic regression     odds_ratio         0.842939  0.162395
# 3   Univariate logistic regression     odds_ratio         0.916363  0.229588
# 4   Univariate logistic regression     odds_ratio         0.999945  0.279449
# 5   Univariate logistic regression     odds_ratio         1.120522  0.309289
# 6   Univariate logistic regression     odds_ratio         0.999878  0.309797
# 7   Univariate logistic regression     odds_ratio         1.097105  0.340917
# 8   Univariate logistic regression     odds_ratio         1.058969  0.437057
# 9   Univariate logistic regression     odds_ratio         1.019278  0.445466
# 10  Univariate logistic regression     odds_ratio         1.064033  0.458539
# 11  Univariate logistic regression     odds_ratio         1.120812  0.493622
# 12  Univariate logistic regression     odds_ratio         0.946672  0.521002
# 13  Univariate logistic regression     odds_ratio         0.999989  0.536114
# 14  Univariate logistic regression     odds_ratio         0.997689  0.543010
# 15  Univariate logistic regression     odds_ratio         1.014740  0.574200
# 16  Univariate logistic regression     odds_ratio         0.997900  0.584221
# 17  Univariate logistic regression     odds_ratio         1.040747  0.628214
# 18  Univariate logistic regression     odds_ratio         1.038591  0.640607
# 19  Univariate logistic regression     odds_ratio         1.082369  0.643781
# 20  Univariate logistic regression     odds_ratio         1.049254  0.653306
# 21  Univariate logistic regression     odds_ratio         1.062712  0.688629
# 22  Univariate logistic regression     odds_ratio         1.041263  0.689453
# 23  Univariate logistic regression     odds_ratio         1.010359  0.694361
# 24  Univariate logistic regression     odds_ratio         0.999960  0.701896
# 25  Univariate logistic regression     odds_ratio         1.044477  0.706103
# 26  Univariate logistic regression     odds_ratio         1.008841  0.724977
# 27  Univariate logistic regression     odds_ratio         0.987207  0.727781
# 28  Univariate logistic regression     odds_ratio         0.948365  0.746483
# 29  Univariate logistic regression     odds_ratio         0.991714  0.749188
# 30  Univariate logistic regression     odds_ratio         0.999963  0.768888
# 31  Univariate logistic regression     odds_ratio         1.000013  0.801752
# 32  Univariate logistic regression     odds_ratio         1.010989  0.832394
# 33  Univariate logistic regression     odds_ratio         0.999983  0.864734
# 34  Univariate logistic regression     odds_ratio         0.998697  0.868537
# 35  Univariate logistic regression     odds_ratio         1.003918  0.878362
# 36  Univariate logistic regression     odds_ratio         0.996345  0.888042
# 37  Univariate logistic regression     odds_ratio         1.002586  0.920943
# 38  Univariate logistic regression     odds_ratio         0.991603  0.930266
# 39  Univariate logistic regression     odds_ratio         0.998723  0.960332
# Test: Chi-square
#                  predictor predictor_type        test statistic_name  \
# 0   neighbourhood_type_S-B         binary  Chi-square           chi2
# 1   neighbourhood_type_S-C         binary  Chi-square           chi2
# 2   neighbourhood_type_G-C         binary  Chi-square           chi2
# 3   neighbourhood_type_G-A         binary  Chi-square           chi2
# 4   neighbourhood_type_G-E         binary  Chi-square           chi2
# 5   neighbourhood_type_S-A         binary  Chi-square           chi2
# 6   neighbourhood_type_G-D         binary  Chi-square           chi2
# 7   neighbourhood_type_S-E         binary  Chi-square           chi2
# 8   neighbourhood_type_S-D         binary  Chi-square           chi2
# 9   neighbourhood_type_G-B         binary  Chi-square           chi2
# 10  neighbourhood_type_G-F         binary  Chi-square           chi2
# 11                     sex         binary  Chi-square           chi2
#
#     statistic_value   p_value
# 0          5.687074  0.017090
# 1          1.359929  0.243550
# 2          0.920193  0.337424
# 3          0.814787  0.366709
# 4          0.547401  0.459382
# 5          0.488279  0.484696
# 6          0.359794  0.548621
# 7          0.195876  0.658071
# 8          0.155946  0.692917
# 9          0.121388  0.727534
# 10         0.104558  0.746427
# 11         0.034526  0.852592
# Test: VIF
#                            predictor predictor_type test statistic_name  \
# 0                 frontal_area_index     continuous  VIF            VIF
# 1  impervious_surface_cover_fraction     continuous  VIF            VIF
# 2                length_primary_road     continuous  VIF            VIF
# 3                         length_e-w     continuous  VIF            VIF
# 4                         noisenight     continuous  VIF            VIF
# 5                            age_bin     continuous  VIF            VIF
#
#    statistic_value
# 0         1.440089
# 1         1.439730
# 2         1.225354
# 3         1.217776
# 4         1.050038
# 5         1.000484

# %% [markdown]
# ## 7. Run predictive modeling suite
# Train regression/classification models per target, capture metrics, coefficients, residuals, and confusion matrices. This corresponds to the supervised-learning stage outlined in the study: EQ variables (temperature, solar access, air/noise pollution) plus morphology feed separate models for cardiovascular, respiratory, sleep/circadian, and mental-health targets. Demographic/socioeconomic controls remain in the feature space to reduce confounding, and model interpretability (coefficients/importances) is used to flag the most influential EQ factors per health dimension.

# %%
# Initialize lists to store results
all_regression_results = []
all_classification_results = []
all_coefficients = []

# Initialize dictionaries for plots and best estimators
all_residual_plots = {}
all_confusion_matrices = {}
best_models = {}

print("Running Predictive Modeling Suite for All Datasets\n")

for name, dataset_with_info in datasets.items():
    print(f"Processing: {name.upper()}...")

    dataset = dataset_with_info["data"]
    feature_types = dataset_with_info["feature_types"]
    target_type = feature_types["target"]

    model_results = run_modeling_suite(
        dataset,
        "target",
        feature_types=feature_types,
        imbalance_strategy=(
            ("sample_weight" if target_type == "continuous" else "class_weight")
            if CLASS_BALANCING
            else "none"
        ),
        use_standard_scaling=STANDARD_SCALING,
        refine_hyperparameters=HYPERPARAMETER_REFINING,
        enable_ohe=ONE_HOT_ENCODING,
        dataset_name=name,
    )

    coef_df = model_results.get("coefficients", pd.DataFrame())
    best_models[name] = model_results.get("best_model_fitted")

    if target_type == "continuous":
        # Collect Regression Results
        reg_df = model_results.get("regression_results", pd.DataFrame())
        if not reg_df.empty:
            reg_df["Dataset"] = name.upper()
            all_regression_results.append(reg_df)

        # Collect Coefficients (regression)
        if not coef_df.empty:
            coef_df["Dataset"] = name.upper()
            all_coefficients.append(coef_df)

        # Collect Residual Plots
        residuals = model_results.get("residuals", {})
        if residuals:
            all_residual_plots[name] = residuals

    else:
        # Collect Classification Results
        clf_df = model_results.get("classification_results", pd.DataFrame())
        if not clf_df.empty:
            clf_df["Dataset"] = name.upper()
            all_classification_results.append(clf_df)

        # Collect Coefficients (classification)
        if not coef_df.empty:
            coef_df["Dataset"] = name.upper()
            all_coefficients.append(coef_df)

        # Collect Confusion Matrices
        cms = model_results.get("confusion_matrices", {})
        if cms:
            all_confusion_matrices[name] = cms
# Out:
# Running Predictive Modeling Suite for All Datasets
#
# Processing: CARDIOVASCULAR...
# Processing: MENTAL_HEALTH...
# Processing: SLEEP_DISORDER...
# Processing: RESPIRATORY...

# %%
# --- Display Summary Results ---

final_reg_df = pd.DataFrame()
final_clf_df = pd.DataFrame()
final_coef_df = pd.DataFrame()

if all_regression_results:
    final_reg_df = pd.concat(all_regression_results, ignore_index=True)
    cols = ["Dataset"] + [c for c in final_reg_df.columns if c != "Dataset"]
    final_reg_df = final_reg_df[cols]

if all_classification_results:
    final_clf_df = pd.concat(all_classification_results, ignore_index=True)
    cols = ["Dataset"] + [c for c in final_clf_df.columns if c != "Dataset"]
    final_clf_df = final_clf_df[cols]

if all_coefficients:
    final_coef_df = pd.concat(all_coefficients, ignore_index=True)
    cols = ["Dataset"] + [c for c in final_coef_df.columns if c != "Dataset"]
    final_coef_df = final_coef_df[cols]

# Per-dataset ordered view: results first, then coefficients
if not (final_reg_df.empty and final_clf_df.empty and final_coef_df.empty):
    print(f"PER-DATASET RESULTS AND COEFFICIENTS")
    for dataset_name in [name.upper() for name in datasets.keys()]:
        print(f"\nDataset: {dataset_name}")
        reg_subset = (
            final_reg_df[final_reg_df["Dataset"] == dataset_name]
            if not final_reg_df.empty
            else pd.DataFrame()
        )
        if not reg_subset.empty:
            print("  Regression results:")
            display(reg_subset)
        clf_subset = (
            final_clf_df[final_clf_df["Dataset"] == dataset_name]
            if not final_clf_df.empty
            else pd.DataFrame()
        )
        if not clf_subset.empty:
            print("  Classification results:")
            display(clf_subset)
        coef_subset = (
            final_coef_df[final_coef_df["Dataset"] == dataset_name]
            if not final_coef_df.empty
            else pd.DataFrame()
        )
        if not coef_subset.empty:
            print("  Coefficients / importances:")
            display(coef_subset)
# Out:
# PER-DATASET RESULTS AND COEFFICIENTS
#
# Dataset: CARDIOVASCULAR
#   Classification results:
#           Dataset  Accuracy  Precision    Recall        F1   ROC_AUC  \
# 0  CARDIOVASCULAR  0.622054   0.114807  0.594444  0.192446  0.631228
# 1  CARDIOVASCULAR  0.723485   0.115942  0.400000  0.179775  0.613330
# 2  CARDIOVASCULAR  0.481061   0.082474  0.577778  0.144344  0.521003
# 3  CARDIOVASCULAR  0.075758   0.075758  1.000000  0.140845  0.473224
# 4  CARDIOVASCULAR  0.075758   0.075758  1.000000  0.140845  0.489031
# 5  CARDIOVASCULAR  0.084175   0.075680  0.988889  0.140600  0.516629
#
#                          model  \
# 0  Logistic Regression (Ridge)
# 1  Logistic Regression (Lasso)
# 2     Random Forest Classifier
# 3                 SVM (Linear)
# 4              k-NN Classifier
# 5                    SVM (RBF)
#
#                                          best_params  threshold
# 0                                 {'model__C': 0.01}   0.082497
# 1                                 {'model__C': 0.01}   0.094073
# 2  {'model__max_depth': None, 'model__n_estimator...   0.003333
# 3                                 {'model__C': 0.01}   0.064714
# 4                          {'model__n_neighbors': 3}   0.000000
# 5         {'model__C': 0.1, 'model__gamma': 'scale'}   0.071850
#   Coefficients / importances:
#            Dataset                        model  \
# 0   CARDIOVASCULAR  Logistic Regression (Ridge)
# 1   CARDIOVASCULAR  Logistic Regression (Ridge)
# 2   CARDIOVASCULAR  Logistic Regression (Ridge)
# 3   CARDIOVASCULAR  Logistic Regression (Ridge)
# 4   CARDIOVASCULAR  Logistic Regression (Ridge)
# 5   CARDIOVASCULAR  Logistic Regression (Ridge)
# 6   CARDIOVASCULAR  Logistic Regression (Ridge)
# 7   CARDIOVASCULAR  Logistic Regression (Ridge)
# 8   CARDIOVASCULAR  Logistic Regression (Ridge)
# 9   CARDIOVASCULAR  Logistic Regression (Ridge)
# 10  CARDIOVASCULAR  Logistic Regression (Ridge)
# 11  CARDIOVASCULAR  Logistic Regression (Ridge)
#
#                             feature  coefficient
# 0                         pm10_mean     0.031490
# 1                         pm25_mean     0.019612
# 2                          no2_mean     0.042242
# 3                        noiseday_m     0.046334
# 4                        noisenight     0.059504
# 5                   sky_view_factor     0.016721
# 6              water_cover_fraction     0.006747
# 7   pervious_surface_cover_fraction     0.043209
# 8                      length_se-nw     0.022584
# 9                    length_railway     0.021984
# 10                           income     0.020418
# 11                          age_bin     0.262351
# Dataset: MENTAL_HEALTH
#   Regression results:
#          Dataset                    model      RMSE       MAE        R2  \
# 0  MENTAL_HEALTH         Lasso Regression  0.321733  0.284275 -0.005725
# 1  MENTAL_HEALTH         Ridge Regression  0.322380  0.284639 -0.009773
# 2  MENTAL_HEALTH        Linear Regression  0.322388  0.284641 -0.009820
# 3  MENTAL_HEALTH                SVR (RBF)  0.323984  0.285690 -0.019847
# 4  MENTAL_HEALTH             Kernel Ridge  0.324685  0.286120 -0.024262
# 5  MENTAL_HEALTH  Random Forest Regressor  0.333006  0.289595 -0.077437
# 6  MENTAL_HEALTH           k-NN Regressor  0.365545  0.307654 -0.298281
#
#                                          best_params
# 0                  {'regressor__model__alpha': 0.01}
# 1                  {'regressor__model__alpha': 10.0}
# 2                                                 {}
# 3  {'regressor__model__C': 0.1, 'regressor__model...
# 4                  {'regressor__model__alpha': 10.0}
# 5  {'regressor__model__max_depth': 10, 'regressor...
# 6               {'regressor__model__n_neighbors': 7}
#   Coefficients / importances:
#           Dataset             model                feature  coefficient
# 12  MENTAL_HEALTH  Lasso Regression               lst_mean    -0.009715
# 13  MENTAL_HEALTH  Lasso Regression              pm10_mean    -0.000000
# 14  MENTAL_HEALTH  Lasso Regression               no2_mean    -0.000000
# 15  MENTAL_HEALTH  Lasso Regression             noiseday_m    -0.000000
# 16  MENTAL_HEALTH  Lasso Regression        sky_view_factor     0.000000
# 17  MENTAL_HEALTH  Lasso Regression     frontal_area_index    -0.000000
# 18  MENTAL_HEALTH  Lasso Regression           aspect_ratio    -0.000000
# 19  MENTAL_HEALTH  Lasso Regression          intersections     0.000000
# 20  MENTAL_HEALTH  Lasso Regression             length_n-s    -0.000000
# 21  MENTAL_HEALTH  Lasso Regression           length_ne-sw    -0.000000
# 22  MENTAL_HEALTH  Lasso Regression    length_primary_road     0.000000
# 23  MENTAL_HEALTH  Lasso Regression  length_secondary_road    -0.028720
# 24  MENTAL_HEALTH  Lasso Regression                    sex    -0.217930
# 25  MENTAL_HEALTH  Lasso Regression                 income    -0.012949
# 26  MENTAL_HEALTH  Lasso Regression        education_level    -0.026607
# 27  MENTAL_HEALTH  Lasso Regression                age_bin    -0.000000
# Dataset: SLEEP_DISORDER
#   Regression results:
#            Dataset                    model      RMSE       MAE        R2  \
# 7   SLEEP_DISORDER         Lasso Regression  0.243225  0.160550 -0.045934
# 8   SLEEP_DISORDER         Ridge Regression  0.243346  0.160959 -0.046975
# 9   SLEEP_DISORDER        Linear Regression  0.243348  0.160960 -0.046997
# 10  SLEEP_DISORDER             Kernel Ridge  0.243820  0.163361 -0.051060
# 11  SLEEP_DISORDER  Random Forest Regressor  0.247670  0.167301 -0.084518
# 12  SLEEP_DISORDER                SVR (RBF)  0.251458  0.158158 -0.117944
# 13  SLEEP_DISORDER           k-NN Regressor  0.258889  0.181569 -0.184996
#
#                                           best_params
# 7                   {'regressor__model__alpha': 0.01}
# 8                   {'regressor__model__alpha': 10.0}
# 9                                                  {}
# 10                  {'regressor__model__alpha': 10.0}
# 11  {'regressor__model__max_depth': 10, 'regressor...
# 12  {'regressor__model__C': 0.1, 'regressor__model...
# 13               {'regressor__model__n_neighbors': 7}
#   Coefficients / importances:
#            Dataset             model              feature  coefficient
# 28  SLEEP_DISORDER  Lasso Regression           solar_summ     0.000000
# 29  SLEEP_DISORDER  Lasso Regression           solar_wint     0.001794
# 30  SLEEP_DISORDER  Lasso Regression            pm10_mean    -0.000000
# 31  SLEEP_DISORDER  Lasso Regression            pm25_mean    -0.000000
# 32  SLEEP_DISORDER  Lasso Regression             no2_mean    -0.000000
# 33  SLEEP_DISORDER  Lasso Regression           noisenight     0.000000
# 34  SLEEP_DISORDER  Lasso Regression      building_height     0.000000
# 35  SLEEP_DISORDER  Lasso Regression    height_varability     0.015226
# 36  SLEEP_DISORDER  Lasso Regression      sky_view_factor     0.000000
# 37  SLEEP_DISORDER  Lasso Regression   frontal_area_index    -0.000000
# 38  SLEEP_DISORDER  Lasso Regression         length_ne-sw     0.005522
# 39  SLEEP_DISORDER  Lasso Regression  length_primary_road     0.000000
# 40  SLEEP_DISORDER  Lasso Regression                  sex    -0.017008
# 41  SLEEP_DISORDER  Lasso Regression               income     0.008161
# 42  SLEEP_DISORDER  Lasso Regression      education_level    -0.004493
# 43  SLEEP_DISORDER  Lasso Regression              age_bin     0.000000
# 44  SLEEP_DISORDER  Lasso Regression           typology_A     0.000000
# 45  SLEEP_DISORDER  Lasso Regression           typology_C    -0.000000
# 46  SLEEP_DISORDER  Lasso Regression           typology_E     0.000000
# 47  SLEEP_DISORDER  Lasso Regression           typology_I    -0.000000
# 48  SLEEP_DISORDER  Lasso Regression           typology_J    -0.000000
# Dataset: RESPIRATORY
#   Classification results:
#         Dataset  Accuracy  Precision    Recall        F1   ROC_AUC  \
# 6   RESPIRATORY  0.201599   0.149977  0.940341  0.258695  0.512750
# 7   RESPIRATORY  0.148148   0.148148  1.000000  0.258065  0.533661
# 8   RESPIRATORY  0.148148   0.148148  1.000000  0.258065  0.502846
# 9   RESPIRATORY  0.148148   0.148148  1.000000  0.258065  0.490748
# 10  RESPIRATORY  0.148148   0.148148  1.000000  0.258065  0.490444
# 11  RESPIRATORY  0.218013   0.148787  0.906250  0.255609  0.506210
#
#                           model  \
# 6   Logistic Regression (Ridge)
# 7   Logistic Regression (Lasso)
# 8      Random Forest Classifier
# 9                     SVM (RBF)
# 10              k-NN Classifier
# 11                 SVM (Linear)
#
#                                           best_params  threshold
# 6                                  {'model__C': 0.01}   0.127397
# 7                                  {'model__C': 0.01}   0.140154
# 8   {'model__max_depth': None, 'model__n_estimator...   0.000000
# 9          {'model__C': 0.1, 'model__gamma': 'scale'}   0.080385
# 10                          {'model__n_neighbors': 3}   0.000000
# 11                                 {'model__C': 0.01}   0.141110
#   Coefficients / importances:
#         Dataset                        model  \
# 49  RESPIRATORY  Logistic Regression (Ridge)
# 50  RESPIRATORY  Logistic Regression (Ridge)
# 51  RESPIRATORY  Logistic Regression (Ridge)
# 52  RESPIRATORY  Logistic Regression (Ridge)
# 53  RESPIRATORY  Logistic Regression (Ridge)
# 54  RESPIRATORY  Logistic Regression (Ridge)
# 55  RESPIRATORY  Logistic Regression (Ridge)
# 56  RESPIRATORY  Logistic Regression (Ridge)
# 57  RESPIRATORY  Logistic Regression (Ridge)
# 58  RESPIRATORY  Logistic Regression (Ridge)
# 59  RESPIRATORY  Logistic Regression (Ridge)
# 60  RESPIRATORY  Logistic Regression (Ridge)
#
#                               feature  coefficient
# 49                         noisenight     0.023883
# 50                 frontal_area_index     0.028193
# 51  impervious_surface_cover_fraction     0.007858
# 52                         length_e-w     0.029725
# 53                length_primary_road     0.044326
# 54                            age_bin     0.096811
# 55             neighbourhood_type_G-A     0.098657
# 56             neighbourhood_type_G-C     0.067525
# 57             neighbourhood_type_G-E     0.169638
# 58             neighbourhood_type_S-A     0.137890
# 59             neighbourhood_type_S-B     0.180005
# 60             neighbourhood_type_S-C     0.216746

# %% [markdown]
# These plots serve as quick diagnostics: residuals highlight bias for regression targets, while confusion matrices show where classifiers mislabel classes.

# %%
# Show residuals for regression datasets or confusion matrices for classification datasets in a single pass
if (all_residual_plots and not final_reg_df.empty) or (
    all_confusion_matrices and not final_clf_df.empty
):
    print("MODEL DIAGNOSTICS (Residuals or Confusion)")
    combined = []
    seen = set()

    if not final_reg_df.empty:
        for ds_name in final_reg_df["Dataset"].unique():
            combined.append(("regression", ds_name))
            seen.add(ds_name)
    if not final_clf_df.empty:
        for ds_name in final_clf_df["Dataset"].unique():
            if ds_name not in seen:
                combined.append(("classification", ds_name))
                seen.add(ds_name)

    if not combined:
        print("No diagnostics to display.")
    else:
        fig, axes = plt.subplots(2, 2, figsize=(14, 10))
        fig.suptitle(
            "Diagnostics (Residuals for regression, Confusion for classification)",
            fontsize=16,
            fontweight="bold",
        )
        axes = axes.flatten()

        for idx, (kind, dataset_name) in enumerate(combined):
            ax = axes[idx]

            if kind == "regression":
                dataset_results = final_reg_df[final_reg_df["Dataset"] == dataset_name]
                if dataset_results.empty:
                    ax.set_visible(False)
                    continue
                best_row = dataset_results.loc[dataset_results["RMSE"].idxmin()]
                model_name = best_row["model"]
                residuals_key = next(
                    (k for k in all_residual_plots if k.upper() == dataset_name), None
                )
                payload = all_residual_plots.get(residuals_key, {}).get(model_name)

                if payload is not None:
                    ax.scatter(payload["pred"], payload["resid"], alpha=0.6)
                    ax.axhline(0, color="red", linestyle="--")
                    ax.set_title(
                        f"{dataset_name}: {model_name} (RMSE: {best_row['RMSE']:.4f})"
                    )
                    ax.set_xlabel("Predicted")
                    ax.set_ylabel("Residual")
                else:
                    ax.text(
                        0.5, 0.5, "Residuals not available", ha="center", va="center"
                    )
                    ax.set_title(f"{dataset_name} (regression)")
            else:
                dataset_results = final_clf_df[final_clf_df["Dataset"] == dataset_name]
                if dataset_results.empty:
                    ax.set_visible(False)
                    continue
                best_row = dataset_results.loc[dataset_results["F1"].idxmax()]
                model_name = best_row["model"]
                cm_key = next(
                    (k for k in all_confusion_matrices if k.upper() == dataset_name),
                    None,
                )
                cm_df = all_confusion_matrices.get(cm_key, {}).get(model_name)

                if cm_df is not None:
                    sns.heatmap(
                        cm_df, annot=True, fmt="g", cmap="Blues", cbar=False, ax=ax
                    )
                    ax.set_title(
                        f"{dataset_name}: {model_name} (F1: {best_row['F1']:.4f})"
                    )
                    ax.set_xlabel("Predicted")
                    ax.set_ylabel("Actual")
                else:
                    ax.text(
                        0.5,
                        0.5,
                        "Confusion matrix not available",
                        ha="center",
                        va="center",
                    )
                    ax.set_title(f"{dataset_name} (classification)")

        plt.tight_layout()
        plt.show()
else:
    print("No residuals or confusion matrices to display.")
# Out:
# MODEL DIAGNOSTICS (Residuals or Confusion)

# %% [markdown]
# ## 8. Results

# %% [markdown]
# ### 8.1 Most predictive features for each of the health risks

# %%
# Post-hoc summary: pick lowest-RMSE model per dataset (regression)
# and pick best-F1 model per dataset (classification); report feature strengths vs. mean

tol = 0.05  # 5% margin for "similar" impacts


def add_relative_strengths(coef_rows: pd.DataFrame) -> tuple[pd.DataFrame, float]:
    coef_rows = coef_rows.copy()
    coef_rows["abs_coef"] = coef_rows["coefficient"].abs()
    mean_abs = coef_rows["abs_coef"].mean()
    mean_abs = float(mean_abs) if not math.isnan(mean_abs) else 0.0
    if mean_abs == 0.0:
        coef_rows["rel_to_mean_abs"] = 0.0
    else:
        coef_rows["rel_to_mean_abs"] = coef_rows["abs_coef"] / mean_abs
    coef_rows = coef_rows.sort_values("abs_coef", ascending=False)
    return coef_rows, mean_abs


# --- Regression (uses RMSE) ---
if final_reg_df is not None and not final_reg_df.empty:
    datasets_with_rmse = final_reg_df["Dataset"].unique()
    for ds in datasets_with_rmse:
        ds_rows = final_reg_df[final_reg_df["Dataset"] == ds]
        best_row = ds_rows.loc[ds_rows["RMSE"].idxmin()]
        best_model = best_row["model"]
        best_rmse = best_row["RMSE"]
        print(f"\n=== {ds} (Regression) ===")
        print(f"Best model (lowest RMSE): {best_model} | RMSE={best_rmse:.4f}")

        coef_rows = final_coef_df[
            (final_coef_df["Dataset"] == ds) & (final_coef_df["model"] == best_model)
        ].copy()
        if coef_rows.empty:
            print("No coefficients/importances stored for this model.")
            continue

        coef_rows, mean_abs = add_relative_strengths(coef_rows)
        print(f"Mean |coef| across features: {mean_abs:.4f}")
        print("Top 5 features with relative strength (|coef| / mean |coef|):")
        display(
            coef_rows.head(5)[["feature", "coefficient", "abs_coef", "rel_to_mean_abs"]]
        )

# --- Classification (uses F1 to pick best) ---
if final_clf_df is not None and not final_clf_df.empty:
    datasets_with_clf = final_clf_df["Dataset"].unique()
    for ds in datasets_with_clf:
        ds_rows = final_clf_df[final_clf_df["Dataset"] == ds]
        best_row = ds_rows.loc[ds_rows["F1"].idxmax()]
        best_model = best_row["model"]
        best_f1 = best_row["F1"]
        print(f"\n=== {ds} (Classification) ===")
        print(f"Best model (highest F1): {best_model} | F1={best_f1:.4f}")

        coef_rows = final_coef_df[
            (final_coef_df["Dataset"] == ds) & (final_coef_df["model"] == best_model)
        ].copy()
        if coef_rows.empty:
            print("No coefficients/importances stored for this model.")
            continue

        coef_rows, mean_abs = add_relative_strengths(coef_rows)
        print(f"Mean |coef| across features: {mean_abs:.4f}")
        print("Top 5 features with relative strength (|coef| / mean |coef|):")
        display(
            coef_rows.head(5)[["feature", "coefficient", "abs_coef", "rel_to_mean_abs"]]
        )
# Out:
# === MENTAL_HEALTH (Regression) ===
# Best model (lowest RMSE): Lasso Regression | RMSE=0.3217
# Mean |coef| across features: 0.0185
# Top 5 features with relative strength (|coef| / mean |coef|):
#                   feature  coefficient  abs_coef  rel_to_mean_abs
# 24                    sex    -0.217930  0.217930        11.783175
# 23  length_secondary_road    -0.028720  0.028720         1.552830
# 26        education_level    -0.026607  0.026607         1.438584
# 25                 income    -0.012949  0.012949         0.700141
# 12               lst_mean    -0.009715  0.009715         0.525270
# === SLEEP_DISORDER (Regression) ===
# Best model (lowest RMSE): Lasso Regression | RMSE=0.2432
# Mean |coef| across features: 0.0025
# Top 5 features with relative strength (|coef| / mean |coef|):
#               feature  coefficient  abs_coef  rel_to_mean_abs
# 40                sex    -0.017008  0.017008         6.841713
# 35  height_varability     0.015226  0.015226         6.124931
# 41             income     0.008161  0.008161         3.282999
# 38       length_ne-sw     0.005522  0.005522         2.221373
# 42    education_level    -0.004493  0.004493         1.807274
# === CARDIOVASCULAR (Classification) ===
# Best model (highest F1): Logistic Regression (Ridge) | F1=0.1924
# Mean |coef| across features: 0.0494
# Top 5 features with relative strength (|coef| / mean |coef|):
#                             feature  coefficient  abs_coef  rel_to_mean_abs
# 11                          age_bin     0.262351  0.262351         5.307189
# 4                        noisenight     0.059504  0.059504         1.203735
# 3                        noiseday_m     0.046334  0.046334         0.937313
# 7   pervious_surface_cover_fraction     0.043209  0.043209         0.874100
# 2                          no2_mean     0.042242  0.042242         0.854521
# === RESPIRATORY (Classification) ===
# Best model (highest F1): Logistic Regression (Ridge) | F1=0.2587
# Mean |coef| across features: 0.0918
# Top 5 features with relative strength (|coef| / mean |coef|):
#                    feature  coefficient  abs_coef  rel_to_mean_abs
# 60  neighbourhood_type_S-C     0.216746  0.216746         2.361805
# 59  neighbourhood_type_S-B     0.180005  0.180005         1.961451
# 57  neighbourhood_type_G-E     0.169638  0.169638         1.848486
# 58  neighbourhood_type_S-A     0.137890  0.137890         1.502537
# 55  neighbourhood_type_G-A     0.098657  0.098657         1.075025

# %% [markdown]
# ### Neighborhood-level risk aggregation

# %% [markdown]
# We now push the trained models back onto the cleaned morphology+EQ grid to get neighborhood-level risk estimates. `infer_neighborhood_health_risks` keeps typology alongside predictions so we can later slice by urban form.

# %%
from src.utils.prediction import infer_neighborhood_health_risks

feature_types_map = {
    dataset_name: dataset_info["feature_types"]
    for dataset_name, dataset_info in datasets.items()
}

health_risks = infer_neighborhood_health_risks(
    best_models=best_models,
    feature_types_map=feature_types_map,
    enable_ohe=ONE_HOT_ENCODING,
    morph_csv_path=data_path / "morphology_data_cleaned.csv",
)

for name, df_risk in health_risks.items():
    print(f"\n{name.upper()} risk table")
    display(df_risk)
# Out:
# CARDIOVASCULAR risk table
#         id income education_level                      age_bin sex  \
# 0       36   <50k         primary       Early Childhood (0-6y)   M
# 1       36   <50k         primary       Early Childhood (0-6y)   F
# 2       36   <50k         primary             Children (6-12y)   M
# 3       36   <50k         primary             Children (6-12y)   F
# 4       36   <50k         primary           Teenagers (12-18y)   M
# ...    ...    ...             ...                          ...  ..
# 40315  466  >150k        tertiary              Adults (30-50y)   F
# 40316  466  >150k        tertiary  Middle-Aged Adults (50-70y)   M
# 40317  466  >150k        tertiary  Middle-Aged Adults (50-70y)   F
# 40318  466  >150k        tertiary          Older Adults (70+y)   M
# 40319  466  >150k        tertiary          Older Adults (70+y)   F
#
#        risk_cardiovascular       pc1       pc2       pc3       pc4  ...  \
# 0                 0.020309  0.526055  0.338480  0.846051 -1.420268  ...
# 1                 0.020309  0.526055  0.338480  0.846051 -1.420268  ...
# 2                 0.025904  0.526055  0.338480  0.846051 -1.420268  ...
# 3                 0.025904  0.526055  0.338480  0.846051 -1.420268  ...
# 4                 0.032989  0.526055  0.338480  0.846051 -1.420268  ...
# ...                    ...       ...       ...       ...       ...  ...
# 40315             0.054687 -0.472228  0.116914 -0.835083 -0.443792  ...
# 40316             0.069086 -0.472228  0.116914 -0.835083 -0.443792  ...
# 40317             0.069086 -0.472228  0.116914 -0.835083 -0.443792  ...
# 40318             0.086928 -0.472228  0.116914 -0.835083 -0.443792  ...
# 40319             0.086928 -0.472228  0.116914 -0.835083 -0.443792  ...
#
#        aspect_ratio  intersections length_n-s  length_ne-sw  length_se-nw  \
# 0             0.391             17     112.14        420.48         83.42
# 1             0.391             17     112.14        420.48         83.42
# 2             0.391             17     112.14        420.48         83.42
# 3             0.391             17     112.14        420.48         83.42
# 4             0.391             17     112.14        420.48         83.42
# ...             ...            ...        ...           ...           ...
# 40315         0.232              5     285.23        360.00        215.65
# 40316         0.232              5     285.23        360.00        215.65
# 40317         0.232              5     285.23        360.00        215.65
# 40318         0.232              5     285.23        360.00        215.65
# 40319         0.232              5     285.23        360.00        215.65
#
#        length_e-w  length_primary_road  length_secondary_road  length_railway  \
# 0          561.10                  0.0                1177.14         375.314
# 1          561.10                  0.0                1177.14         375.314
# 2          561.10                  0.0                1177.14         375.314
# 3          561.10                  0.0                1177.14         375.314
# 4          561.10                  0.0                1177.14         375.314
# ...           ...                  ...                    ...             ...
# 40315       28.77                  0.0                 889.65           0.000
# 40316       28.77                  0.0                 889.65           0.000
# 40317       28.77                  0.0                 889.65           0.000
# 40318       28.77                  0.0                 889.65           0.000
# 40319       28.77                  0.0                 889.65           0.000
#
#        neighbourhood_type
# 0                     S-C
# 1                     S-C
# 2                     S-C
# 3                     S-C
# 4                     S-C
# ...                   ...
# 40315                 S-C
# 40316                 S-C
# 40317                 S-C
# 40318                 S-C
# 40319                 S-C
#
# [40320 rows x 39 columns]
# MENTAL_HEALTH risk table
#         id income education_level                      age_bin sex  \
# 0       36   <50k         primary       Early Childhood (0-6y)   M
# 1       36   <50k         primary       Early Childhood (0-6y)   F
# 2       36   <50k         primary             Children (6-12y)   M
# 3       36   <50k         primary             Children (6-12y)   F
# 4       36   <50k         primary           Teenagers (12-18y)   M
# ...    ...    ...             ...                          ...  ..
# 40315  466  >150k        tertiary              Adults (30-50y)   F
# 40316  466  >150k        tertiary  Middle-Aged Adults (50-70y)   M
# 40317  466  >150k        tertiary  Middle-Aged Adults (50-70y)   F
# 40318  466  >150k        tertiary          Older Adults (70+y)   M
# 40319  466  >150k        tertiary          Older Adults (70+y)   F
#
#        risk_mental_health       pc1       pc2       pc3       pc4  ...  \
# 0                0.651472  0.526055  0.338480  0.846051 -1.420268  ...
# 1                0.651472  0.526055  0.338480  0.846051 -1.420268  ...
# 2                0.645715  0.526055  0.338480  0.846051 -1.420268  ...
# 3                0.645715  0.526055  0.338480  0.846051 -1.420268  ...
# 4                0.639915  0.526055  0.338480  0.846051 -1.420268  ...
# ...                   ...       ...       ...       ...       ...  ...
# 40315            0.463648 -0.472228  0.116914 -0.835083 -0.443792  ...
# 40316            0.457372 -0.472228  0.116914 -0.835083 -0.443792  ...
# 40317            0.457372 -0.472228  0.116914 -0.835083 -0.443792  ...
# 40318            0.451110 -0.472228  0.116914 -0.835083 -0.443792  ...
# 40319            0.451110 -0.472228  0.116914 -0.835083 -0.443792  ...
#
#        aspect_ratio  intersections length_n-s  length_ne-sw  length_se-nw  \
# 0             0.391             17     112.14        420.48         83.42
# 1             0.391             17     112.14        420.48         83.42
# 2             0.391             17     112.14        420.48         83.42
# 3             0.391             17     112.14        420.48         83.42
# 4             0.391             17     112.14        420.48         83.42
# ...             ...            ...        ...           ...           ...
# 40315         0.232              5     285.23        360.00        215.65
# 40316         0.232              5     285.23        360.00        215.65
# 40317         0.232              5     285.23        360.00        215.65
# 40318         0.232              5     285.23        360.00        215.65
# 40319         0.232              5     285.23        360.00        215.65
#
#        length_e-w  length_primary_road  length_secondary_road  length_railway  \
# 0          561.10                  0.0                1177.14         375.314
# 1          561.10                  0.0                1177.14         375.314
# 2          561.10                  0.0                1177.14         375.314
# 3          561.10                  0.0                1177.14         375.314
# 4          561.10                  0.0                1177.14         375.314
# ...           ...                  ...                    ...             ...
# 40315       28.77                  0.0                 889.65           0.000
# 40316       28.77                  0.0                 889.65           0.000
# 40317       28.77                  0.0                 889.65           0.000
# 40318       28.77                  0.0                 889.65           0.000
# 40319       28.77                  0.0                 889.65           0.000
#
#        neighbourhood_type
# 0                     S-C
# 1                     S-C
# 2                     S-C
# 3                     S-C
# 4                     S-C
# ...                   ...
# 40315                 S-C
# 40316                 S-C
# 40317                 S-C
# 40318                 S-C
# 40319                 S-C
#
# [40320 rows x 39 columns]
# SLEEP_DISORDER risk table
#         id income education_level                      age_bin sex  \
# 0       36   <50k         primary       Early Childhood (0-6y)   M
# 1       36   <50k         primary       Early Childhood (0-6y)   F
# 2       36   <50k         primary             Children (6-12y)   M
# 3       36   <50k         primary             Children (6-12y)   F
# 4       36   <50k         primary           Teenagers (12-18y)   M
# ...    ...    ...             ...                          ...  ..
# 40315  466  >150k        tertiary              Adults (30-50y)   F
# 40316  466  >150k        tertiary  Middle-Aged Adults (50-70y)   M
# 40317  466  >150k        tertiary  Middle-Aged Adults (50-70y)   F
# 40318  466  >150k        tertiary          Older Adults (70+y)   M
# 40319  466  >150k        tertiary          Older Adults (70+y)   F
#
#        risk_sleep_disorder       pc1       pc2       pc3       pc4  ...  \
# 0                 0.216580  0.526055  0.338480  0.846051 -1.420268  ...
# 1                 0.216580  0.526055  0.338480  0.846051 -1.420268  ...
# 2                 0.215857  0.526055  0.338480  0.846051 -1.420268  ...
# 3                 0.215857  0.526055  0.338480  0.846051 -1.420268  ...
# 4                 0.215136  0.526055  0.338480  0.846051 -1.420268  ...
# ...                    ...       ...       ...       ...       ...  ...
# 40315             0.209130 -0.472228  0.116914 -0.835083 -0.443792  ...
# 40316             0.208425 -0.472228  0.116914 -0.835083 -0.443792  ...
# 40317             0.208425 -0.472228  0.116914 -0.835083 -0.443792  ...
# 40318             0.207722 -0.472228  0.116914 -0.835083 -0.443792  ...
# 40319             0.207722 -0.472228  0.116914 -0.835083 -0.443792  ...
#
#        aspect_ratio  intersections length_n-s  length_ne-sw  length_se-nw  \
# 0             0.391             17     112.14        420.48         83.42
# 1             0.391             17     112.14        420.48         83.42
# 2             0.391             17     112.14        420.48         83.42
# 3             0.391             17     112.14        420.48         83.42
# 4             0.391             17     112.14        420.48         83.42
# ...             ...            ...        ...           ...           ...
# 40315         0.232              5     285.23        360.00        215.65
# 40316         0.232              5     285.23        360.00        215.65
# 40317         0.232              5     285.23        360.00        215.65
# 40318         0.232              5     285.23        360.00        215.65
# 40319         0.232              5     285.23        360.00        215.65
#
#        length_e-w  length_primary_road  length_secondary_road  length_railway  \
# 0          561.10                  0.0                1177.14         375.314
# 1          561.10                  0.0                1177.14         375.314
# 2          561.10                  0.0                1177.14         375.314
# 3          561.10                  0.0                1177.14         375.314
# 4          561.10                  0.0                1177.14         375.314
# ...           ...                  ...                    ...             ...
# 40315       28.77                  0.0                 889.65           0.000
# 40316       28.77                  0.0                 889.65           0.000
# 40317       28.77                  0.0                 889.65           0.000
# 40318       28.77                  0.0                 889.65           0.000
# 40319       28.77                  0.0                 889.65           0.000
#
#        neighbourhood_type
# 0                     S-C
# 1                     S-C
# 2                     S-C
# 3                     S-C
# 4                     S-C
# ...                   ...
# 40315                 S-C
# 40316                 S-C
# 40317                 S-C
# 40318                 S-C
# 40319                 S-C
#
# [40320 rows x 39 columns]
# RESPIRATORY risk table
#         id income education_level                      age_bin sex  \
# 0       36   <50k         primary       Early Childhood (0-6y)   M
# 1       36   <50k         primary       Early Childhood (0-6y)   F
# 2       36   <50k         primary             Children (6-12y)   M
# 3       36   <50k         primary             Children (6-12y)   F
# 4       36   <50k         primary           Teenagers (12-18y)   M
# ...    ...    ...             ...                          ...  ..
# 40315  466  >150k        tertiary              Adults (30-50y)   F
# 40316  466  >150k        tertiary  Middle-Aged Adults (50-70y)   M
# 40317  466  >150k        tertiary  Middle-Aged Adults (50-70y)   F
# 40318  466  >150k        tertiary          Older Adults (70+y)   M
# 40319  466  >150k        tertiary          Older Adults (70+y)   F
#
#        risk_respiratory       pc1       pc2       pc3       pc4  ...  \
# 0              0.090028  0.526055  0.338480  0.846051 -1.420268  ...
# 1              0.090028  0.526055  0.338480  0.846051 -1.420268  ...
# 2              0.097847  0.526055  0.338480  0.846051 -1.420268  ...
# 3              0.097847  0.526055  0.338480  0.846051 -1.420268  ...
# 4              0.106266  0.526055  0.338480  0.846051 -1.420268  ...
# ...                 ...       ...       ...       ...       ...  ...
# 40315          0.134379 -0.472228  0.116914 -0.835083 -0.443792  ...
# 40316          0.145435 -0.472228  0.116914 -0.835083 -0.443792  ...
# 40317          0.145435 -0.472228  0.116914 -0.835083 -0.443792  ...
# 40318          0.157234 -0.472228  0.116914 -0.835083 -0.443792  ...
# 40319          0.157234 -0.472228  0.116914 -0.835083 -0.443792  ...
#
#        aspect_ratio  intersections length_n-s  length_ne-sw  length_se-nw  \
# 0             0.391             17     112.14        420.48         83.42
# 1             0.391             17     112.14        420.48         83.42
# 2             0.391             17     112.14        420.48         83.42
# 3             0.391             17     112.14        420.48         83.42
# 4             0.391             17     112.14        420.48         83.42
# ...             ...            ...        ...           ...           ...
# 40315         0.232              5     285.23        360.00        215.65
# 40316         0.232              5     285.23        360.00        215.65
# 40317         0.232              5     285.23        360.00        215.65
# 40318         0.232              5     285.23        360.00        215.65
# 40319         0.232              5     285.23        360.00        215.65
#
#        length_e-w  length_primary_road  length_secondary_road  length_railway  \
# 0          561.10                  0.0                1177.14         375.314
# 1          561.10                  0.0                1177.14         375.314
# 2          561.10                  0.0                1177.14         375.314
# 3          561.10                  0.0                1177.14         375.314
# 4          561.10                  0.0                1177.14         375.314
# ...           ...                  ...                    ...             ...
# 40315       28.77                  0.0                 889.65           0.000
# 40316       28.77                  0.0                 889.65           0.000
# 40317       28.77                  0.0                 889.65           0.000
# 40318       28.77                  0.0                 889.65           0.000
# 40319       28.77                  0.0                 889.65           0.000
#
#        neighbourhood_type
# 0                     S-C
# 1                     S-C
# 2                     S-C
# 3                     S-C
# 4                     S-C
# ...                   ...
# 40315                 S-C
# 40316                 S-C
# 40317                 S-C
# 40318                 S-C
# 40319                 S-C
#
# [40320 rows x 39 columns]

# %%
# let's checkout the health risks related to the neighborhood with id 36

neighborhood_id = 36
for name, df_risk in health_risks.items():
    print(f"\n{name.upper()} risk table")
    neighborhood_df = df_risk[df_risk["id"] == neighborhood_id]
    display(neighborhood_df[neighborhood_df.columns[:6]])
# Out:
# CARDIOVASCULAR risk table
#      id income education_level                      age_bin sex  \
# 0    36   <50k         primary       Early Childhood (0-6y)   M
# 1    36   <50k         primary       Early Childhood (0-6y)   F
# 2    36   <50k         primary             Children (6-12y)   M
# 3    36   <50k         primary             Children (6-12y)   F
# 4    36   <50k         primary           Teenagers (12-18y)   M
# ..   ..    ...             ...                          ...  ..
# 163  36  >150k        tertiary              Adults (30-50y)   F
# 164  36  >150k        tertiary  Middle-Aged Adults (50-70y)   M
# 165  36  >150k        tertiary  Middle-Aged Adults (50-70y)   F
# 166  36  >150k        tertiary          Older Adults (70+y)   M
# 167  36  >150k        tertiary          Older Adults (70+y)   F
#
#      risk_cardiovascular
# 0               0.020309
# 1               0.020309
# 2               0.025904
# 3               0.025904
# 4               0.032989
# ..                   ...
# 163             0.050138
# 164             0.063420
# 165             0.063420
# 166             0.079924
# 167             0.079924
#
# [168 rows x 6 columns]
# MENTAL_HEALTH risk table
#      id income education_level                      age_bin sex  \
# 0    36   <50k         primary       Early Childhood (0-6y)   M
# 1    36   <50k         primary       Early Childhood (0-6y)   F
# 2    36   <50k         primary             Children (6-12y)   M
# 3    36   <50k         primary             Children (6-12y)   F
# 4    36   <50k         primary           Teenagers (12-18y)   M
# ..   ..    ...             ...                          ...  ..
# 163  36  >150k        tertiary              Adults (30-50y)   F
# 164  36  >150k        tertiary  Middle-Aged Adults (50-70y)   M
# 165  36  >150k        tertiary  Middle-Aged Adults (50-70y)   F
# 166  36  >150k        tertiary          Older Adults (70+y)   M
# 167  36  >150k        tertiary          Older Adults (70+y)   F
#
#      risk_mental_health
# 0              0.651472
# 1              0.651472
# 2              0.645715
# 3              0.645715
# 4              0.639915
# ..                  ...
# 163            0.457387
# 164            0.451125
# 165            0.451125
# 166            0.444878
# 167            0.444878
#
# [168 rows x 6 columns]
# SLEEP_DISORDER risk table
#      id income education_level                      age_bin sex  \
# 0    36   <50k         primary       Early Childhood (0-6y)   M
# 1    36   <50k         primary       Early Childhood (0-6y)   F
# 2    36   <50k         primary             Children (6-12y)   M
# 3    36   <50k         primary             Children (6-12y)   F
# 4    36   <50k         primary           Teenagers (12-18y)   M
# ..   ..    ...             ...                          ...  ..
# 163  36  >150k        tertiary              Adults (30-50y)   F
# 164  36  >150k        tertiary  Middle-Aged Adults (50-70y)   M
# 165  36  >150k        tertiary  Middle-Aged Adults (50-70y)   F
# 166  36  >150k        tertiary          Older Adults (70+y)   M
# 167  36  >150k        tertiary          Older Adults (70+y)   F
#
#      risk_sleep_disorder
# 0               0.216580
# 1               0.216580
# 2               0.215857
# 3               0.215857
# 4               0.215136
# ..                   ...
# 163             0.209036
# 164             0.208331
# 165             0.208331
# 166             0.207629
# 167             0.207629
#
# [168 rows x 6 columns]
# RESPIRATORY risk table
#      id income education_level                      age_bin sex  \
# 0    36   <50k         primary       Early Childhood (0-6y)   M
# 1    36   <50k         primary       Early Childhood (0-6y)   F
# 2    36   <50k         primary             Children (6-12y)   M
# 3    36   <50k         primary             Children (6-12y)   F
# 4    36   <50k         primary           Teenagers (12-18y)   M
# ..   ..    ...             ...                          ...  ..
# 163  36  >150k        tertiary              Adults (30-50y)   F
# 164  36  >150k        tertiary  Middle-Aged Adults (50-70y)   M
# 165  36  >150k        tertiary  Middle-Aged Adults (50-70y)   F
# 166  36  >150k        tertiary          Older Adults (70+y)   M
# 167  36  >150k        tertiary          Older Adults (70+y)   F
#
#      risk_respiratory
# 0            0.090028
# 1            0.090028
# 2            0.097847
# 3            0.097847
# 4            0.106266
# ..                ...
# 163          0.125030
# 164          0.135436
# 165          0.135436
# 166          0.146564
# 167          0.146564
#
# [168 rows x 6 columns]

# %% [markdown]
# Finally, condense the neighborhood-level risks by typology to see which urban forms carry higher modeled burden across the four health dimensions. This is the quick policy-facing table for spotting resilient or vulnerable typologies.

# %%
# Average health risk per typology across all socio-demographic combinations (wide view)

rows = []
for name, df_risk in health_risks.items():
    risk_col = f"risk_{name}"
    if risk_col not in df_risk.columns:
        print(f"Skipping {name}: column '{risk_col}' not found.")
        continue
    grouped = (
        df_risk.groupby("typology")[risk_col]
        .mean()
        .reset_index()
        .rename(columns={risk_col: name})
    )
    rows.append(grouped)

if rows:
    combined = rows[0]
    for g in rows[1:]:
        combined = combined.merge(g, on="typology", how="outer")
    combined = combined.sort_values("typology")
    print("Average risk by typology (one column per dataset)")
    display(combined)
else:
    print("No risk data available to summarize.")
# Out:
# Average risk by typology (one column per dataset)
#   typology  cardiovascular  mental_health  sleep_disorder  respiratory
# 0        A        0.056229       0.559081        0.213852     0.132270
# 1        B        0.054645       0.545630        0.213972     0.140464
# 2        C        0.057893       0.548703        0.212388     0.136019
# 3        D        0.055307       0.555202        0.216415     0.134657
# 4        E        0.056421       0.561519        0.213161     0.132382
# 5        F        0.070218       0.561771        0.211342     0.124120
# 6        G        0.056432       0.553871        0.211791     0.131535
# 7        I        0.055401       0.562730        0.209422     0.149970
# 8        J        0.063812       0.564742        0.206757     0.153345

# %%
# Flag typologies with elevated modeled risk per dataset (no melting)

risk_cols = [c for c in combined.columns if c != "typology"]
for col in risk_cols:
    df = combined[["typology", col]].rename(columns={col: "risk"})

    mean_risk = df["risk"].mean()
    std_risk = df["risk"].std()
    zscores = (df["risk"] - mean_risk) / std_risk if std_risk else float("nan")
    df = df.assign(zscore=zscores.round(2))

    high = df[df["zscore"] >= 1.5].sort_values("zscore", ascending=False)
    low = df[df["zscore"] <= -1.5].sort_values("zscore", ascending=True)

    print(f"\n{col.upper()} health risk")

    if not high.empty:
        print(f"\nTypologies with alarmingly higher {col} risk (z >= 1.5):")
        display(high[["typology", "risk", "zscore"]])

    if not low.empty:
        print(f"\nTypologies with exceptionally lower {col} risk (z <= -1.5):")
        display(low[["typology", "risk", "zscore"]])

    print("\nPer-typology risk with zscore: ")
    display(df.sort_values("risk", ascending=False)[["typology", "risk", "zscore"]])
# Out:
# CARDIOVASCULAR health risk
#
# Typologies with alarmingly higher cardiovascular risk (z >= 1.5):
#   typology      risk  zscore
# 5        F  0.070218    2.27
# Per-typology risk with zscore:
#   typology      risk  zscore
# 5        F  0.070218    2.27
# 8        J  0.063812    1.03
# 2        C  0.057893   -0.11
# 6        G  0.056432   -0.40
# 4        E  0.056421   -0.40
# 0        A  0.056229   -0.44
# 7        I  0.055401   -0.60
# 3        D  0.055307   -0.61
# 1        B  0.054645   -0.74
# MENTAL_HEALTH health risk
#
# Typologies with exceptionally lower mental_health risk (z <= -1.5):
#   typology     risk  zscore
# 1        B  0.54563   -1.72
# Per-typology risk with zscore:
#   typology      risk  zscore
# 8        J  0.564742    1.16
# 7        I  0.562730    0.86
# 5        F  0.561771    0.72
# 4        E  0.561519    0.68
# 0        A  0.559081    0.31
# 3        D  0.555202   -0.28
# 6        G  0.553871   -0.48
# 2        C  0.548703   -1.26
# 1        B  0.545630   -1.72
# SLEEP_DISORDER health risk
#
# Typologies with alarmingly higher sleep_disorder risk (z >= 1.5):
#   typology      risk  zscore
# 3        D  0.216415    1.53
# Typologies with exceptionally lower sleep_disorder risk (z <= -1.5):
#   typology      risk  zscore
# 8        J  0.206757   -1.92
# Per-typology risk with zscore:
#   typology      risk  zscore
# 3        D  0.216415    1.53
# 1        B  0.213972    0.66
# 0        A  0.213852    0.62
# 4        E  0.213161    0.37
# 2        C  0.212388    0.09
# 6        G  0.211791   -0.12
# 5        F  0.211342   -0.28
# 7        I  0.209422   -0.96
# 8        J  0.206757   -1.92
# RESPIRATORY health risk
#
# Typologies with alarmingly higher respiratory risk (z >= 1.5):
#   typology      risk  zscore
# 8        J  0.153345    1.74
# Per-typology risk with zscore:
#   typology      risk  zscore
# 8        J  0.153345    1.74
# 7        I  0.149970    1.37
# 1        B  0.140464    0.35
# 2        C  0.136019   -0.13
# 3        D  0.134657   -0.27
# 4        E  0.132382   -0.52
# 0        A  0.132270   -0.53
# 6        G  0.131535   -0.61
# 5        F  0.124120   -1.40
